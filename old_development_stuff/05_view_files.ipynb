# %% [markdown]
# # View files
#
# Now that we have the raw images and the raw labels, we can start viewing each file to see whether they look correct (i.e. are not in the wrong orientation) and have been completely annotated. To view these files, we will use nibabel and matplotlib.

# %%
import napari
import torchio as tio
import os
from pathlib import Path
import numpy as np
import pandas as pd

img_dir = './dataset/images/'
label_dir = './dataset/labels/'

info = pd.read_csv('raw_image_info.csv')

# %% [markdown]
# Let's display what info we have available in our csv file

# %%
info
# Out:
#                                       image_file_path  \
# 0                  dataset/images/diurnal_tarsata.nii
# 1                dataset/images/dampieri_20151218.nii
# 2   dataset/images/dampieri_20200218_male_left_167...
# 3                 dataset/images/dampieri_male_16.nii
# 4                dataset/images/flammula_20180307.nii
# 5      dataset/images/flammula_20190925_male_left.nii
# 6   dataset/images/flammula_20200327_female_left_1...
# 7     dataset/images/neohelice_20190616_1_cropped.nii
# 8       dataset/images/Hyperia_02_head_FEG190604_014C
# 9       dataset/images/Hyperia_01_head_FEG190604_014B
# 10   dataset/images/Leptocotis_02_head_FEG190214_005b
# 11  dataset/images/P_crassipes_FEG190213_003b_02_head
# 12  dataset/images/P_crassipes_FEG190801_034_00001...
# 13  dataset/images/P_crassipes_FEG191022_077A_high...
# 14      dataset/images/P_crassipes_FEG191022_077B.nii
# 15   dataset/images/P_crassipes_FEG200129_099_cropped
# 16  dataset/images/P_crassipes_FEG200205_108_crop.nii
# 17  dataset/images/P_gracilis_FEG190213_003a_head.nii
# 18       dataset/images/P_robisoni_FEG200205_105-head
# 19  dataset/images/Paraphronima_FEG181024_03_head_...
# 20  dataset/images/Paraphronima_FEG181024_head_sp_...
# 21  dataset/images/Paraphronima_FEG181024_head_sp_...
# 22          dataset/images/Paraphronima_FEG191028_078
# 23  dataset/images/Paraphronima_head_04_FEG200130_103
# 24  dataset/images/Paraphronima_head_05_FEG200130_102
# 25       dataset/images/Phronima_04_FEG200107_089.nii
# 26       dataset/images/Phronima_05_FEG200107_090.nii
# 27               dataset/images/phronima_20180403.nii
# 28                   dataset/images/20190608_phronima
# 29  dataset/images/Platyscelus_02_FEG191112_082_do...
# 30     dataset/images/psyllid_20190906_female_eye.nii
# 31       dataset/images/psyllid_20190906_male_eye.nii
# 32             dataset/images/flammula_male_23_6_left
# 33                    dataset/images/Brachyscelus.nii
# 34      dataset/images/platyscelus_01_downsampled.nii
# 35              dataset/images/streetsia_20180409.nii
# 36                  dataset/images/streetsia_20190308
# 37                  dataset/images/streetsia_20190325
#
#                               raw_annotated_file_path         status  swap_xy  \
# 0   //home/jake/projects/mctv_resfiles/ants/diurna...           good    False
# 1   //home/jake/projects/mctv_resfiles/fiddlercrab...           good    False
# 2   //home/jake/projects/mctv_resfiles/fiddlercrab...           good    False
# 3   //home/jake/projects/mctv_resfiles/fiddlercrab...  good but crop    False
# 4   //home/jake/projects/mctv_resfiles/fiddlercrab...           good    False
# 5   //home/jake/projects/mctv_resfiles/fiddlercrab...  good but crop    False
# 6   //home/jake/projects/mctv_resfiles/fiddlercrab...  good but crop    False
# 7   //home/jake/projects/mctv_resfiles/fiddlercrab...  good but crop    False
# 8   //home/jake/projects/mctv_resfiles/hyperiids/h...  good but crop    False
# 9   //home/jake/projects/mctv_resfiles/hyperiids/h...           good    False
# 10  //home/jake/projects/mctv_resfiles/hyperiids/L...            NaN    False
# 11  //home/jake/projects/mctv_resfiles/hyperiids/P...            NaN    False
# 12  //home/jake/projects/mctv_resfiles/hyperiids/P...            NaN    False
# 13  //home/jake/projects/mctv_resfiles/hyperiids/P...            NaN    False
# 14  //home/jake/projects/mctv_resfiles/hyperiids/P...            NaN    False
# 15  //home/jake/projects/mctv_resfiles/hyperiids/P...            NaN    False
# 16  //home/jake/projects/mctv_resfiles/hyperiids/P...            NaN    False
# 17  //home/jake/projects/mctv_resfiles/hyperiids/P...            NaN    False
# 18  //home/jake/projects/mctv_resfiles/hyperiids/P...            NaN    False
# 19  //home/jake/projects/mctv_resfiles/hyperiids/P...            NaN    False
# 20  //home/jake/projects/mctv_resfiles/hyperiids/P...            NaN    False
# 21  //home/jake/projects/mctv_resfiles/hyperiids/P...            NaN    False
# 22  //home/jake/projects/mctv_resfiles/hyperiids/P...            NaN    False
# 23  //home/jake/projects/mctv_resfiles/hyperiids/P...            NaN    False
# 24  //home/jake/projects/mctv_resfiles/hyperiids/P...            NaN    False
# 25  //home/jake/projects/mctv_resfiles/hyperiids/P...            NaN    False
# 26  //home/jake/projects/mctv_resfiles/hyperiids/P...            NaN    False
# 27  //home/jake/projects/mctv_resfiles/hyperiids/p...            NaN    False
# 28  //home/jake/projects/mctv_resfiles/hyperiids/p...            NaN    False
# 29  //home/jake/projects/mctv_resfiles/hyperiids/P...            NaN    False
# 30  //home/jake/projects/mctv_resfiles/psyllids/ps...            NaN    False
# 31  //home/jake/projects/mctv_resfiles/psyllids/ps...            NaN    False
# 32  //media/jake/1tb_ssd/mctv_analysis/mctv_resfil...            NaN    False
# 33  //media/jake/1tb_ssd/mctv_analysis/mctv_resfil...            NaN    False
# 34  //media/jake/1tb_ssd/mctv_analysis/mctv_resfil...            NaN    False
# 35  //media/jake/1tb_ssd/mctv_analysis/mctv_resfil...            NaN    False
# 36  //media/jake/1tb_ssd/mctv_analysis/mctv_resfil...            NaN    False
# 37  //media/jake/1tb_ssd/mctv_analysis/mctv_resfil...            NaN    False
#
#     flip_y  check  old_swap_xy  old_flip_y  \
# 0    False    NaN        False       False
# 1    False    NaN        False       False
# 2    False    NaN        False       False
# 3    False    NaN        False       False
# 4    False    NaN        False       False
# 5    False    NaN        False       False
# 6    False    NaN        False       False
# 7    False    NaN        False       False
# 8    False    NaN        False       False
# 9    False    NaN        False       False
# 10   False    NaN         True        True
# 11   False    NaN         True        True
# 12   False    NaN         True        True
# 13   False    NaN         True        True
# 14   False    NaN         True        True
# 15   False    NaN         True       False
# 16   False    NaN         True        True
# 17   False    NaN         True        True
# 18   False    NaN         True        True
# 19   False    NaN         True        True
# 20   False    NaN         True        True
# 21   False    NaN         True        True
# 22   False    NaN         True        True
# 23   False    NaN         True        True
# 24   False    NaN         True        True
# 25   False    NaN        False       False
# 26   False    NaN        False       False
# 27   False    NaN        False       False
# 28   False    NaN         True        True
# 29   False    NaN         True        True
# 30   False    NaN        False       False
# 31   False    NaN        False       False
# 32   False    NaN         True        True
# 33   False    NaN         True        True
# 34   False    NaN         True        True
# 35   False    NaN        False       False
# 36   False    NaN         True        True
# 37   False    NaN        False       False
#
#                                             OLD check  \
# 0                                                good
# 1                                                good
# 2   good (possibly hard to see missing ones at edges)
# 3                                      needs cropping
# 4                                                good
# 5                                      needs cropping
# 6                                      needs cropping
# 7                                      needs cropping
# 8                          wrong orientation or image
# 9                                                good
# 10                         wrong orientation or image
# 11                                               good
# 12  wrong orientation (needs x and z swapped inste...
# 13       Wrong image file – can’t find matching image
# 14                                               good
# 15                    regenerate using these settings
# 16                                        wrong image
# 17                                        wrong image
# 18                                        wrong image
# 19                                        wrong image
# 20  good, but looks like rhabdoms have been sucked...
# 21                                               good
# 22                       good, but very small markers
# 23                       good, but very small markers
# 24  orientation correct, but some rhabdoms have be...
# 25                                               good
# 26                                               good
# 27  most of dorsal eyes done, needs cropping, but ...
# 28                                               good
# 29                         wrong image or orientation
# 30                                               good
# 31                                         incomplete
# 32                   incomplete and wrong orientation
# 33                   incomplete and wrong orientation
# 34                   incomplete and wrong orientation
# 35  wrong orientation try regenerating using these...
# 36                            good but right eye only
# 37  wrong orientation try regenerating using these...
#
#         has correct spacing  needs_cropping_after_creation  \
# 0                     FALSE                          False
# 1                     FALSE                          False
# 2                     FALSE                          False
# 3                     FALSE                           True
# 4                     FALSE                          False
# 5                     FALSE                           True
# 6                     FALSE                           True
# 7                     FALSE                           True
# 8                     FALSE                          False
# 9                     FALSE                          False
# 10                     TRUE                           True
# 11                     TRUE                          False
# 12                     TRUE                          False
# 13                      NaN                          False
# 14                     TRUE                          False
# 15  has weird double z axis                          False
# 16                      NaN                          False
# 17                      NaN                          False
# 18                      NaN                          False
# 19                      NaN                          False
# 20                     TRUE                          False
# 21                     TRUE                          False
# 22                     TRUE                          False
# 23                     TRUE                          False
# 24                     TRUE                          False
# 25                    FALSE                          False
# 26                    FALSE                          False
# 27                    FALSE                           True
# 28                     TRUE                          False
# 29                    FALSE                           True
# 30                    FALSE                          False
# 31                    FALSE                           True
# 32                     TRUE                           True
# 33                    FALSE                           True
# 34                    FALSE                           True
# 35                    FALSE                          False
# 36                    FALSE                           True
# 37                    FALSE                          False
#
#                                           other notes
# 0   data with incorrect spacing have irregular siz...
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12                                                NaN
# 13                                                NaN
# 14                                                NaN
# 15                                                NaN
# 16                                                NaN
# 17                                                NaN
# 18                                                NaN
# 19                                                NaN
# 20                                                NaN
# 21                                                NaN
# 22                                                NaN
# 23                                                NaN
# 24                                                NaN
# 25                                                NaN
# 26                                                NaN
# 27                                                NaN
# 28                                                NaN
# 29                                                NaN
# 30                                                NaN
# 31                                                NaN
# 32                                                NaN
# 33                                                NaN
# 34                                                NaN
# 35                                                NaN
# 36                                                NaN
# 37                                                NaN

# %% [markdown]
# I can see that we have the paths to our images (they are either nifti files or dicom directories). These should be easy to calculate with the following:

# %%
images = info.image_file_path

# replace dicom files with their converted nifti alternative
for i, image in enumerate(images):
    if os.path.isdir(image):
        images.iloc[i] = image + '.nii'

images[:10]
# Out:
# 0                   dataset/images/diurnal_tarsata.nii
# 1                 dataset/images/dampieri_20151218.nii
# 2    dataset/images/dampieri_20200218_male_left_167...
# 3                  dataset/images/dampieri_male_16.nii
# 4                 dataset/images/flammula_20180307.nii
# 5       dataset/images/flammula_20190925_male_left.nii
# 6    dataset/images/flammula_20200327_female_left_1...
# 7      dataset/images/neohelice_20190616_1_cropped.nii
# 8    dataset/images/Hyperia_02_head_FEG190604_014C.nii
# 9    dataset/images/Hyperia_01_head_FEG190604_014B.nii
# Name: image_file_path, dtype: object

# %% [markdown]
# The labels are a bit more difficult to locate. To get these, we will use the stem of the image name.

# %%
from pathlib import Path

labels = []
for image in images:
    p = Path(image)
    label_name = label_dir + p.stem + '.nii'
    labels.append(label_name)

# %%
print(f'Found {len(labels)} labelled images for analysis')
# Out:
# Found 38 labelled images for analysis

# %% [markdown]
# These files are huge, so we need to use nibabel proxy slicing to collect only the data we need for the plot.
# Let's prepare by making some nice functions that can load all our images, get the slices we need and plot them.

# %%
import matplotlib.pyplot as plt
from matplotlib import colors
import nibabel as nib
import nibabel.nicom.dicomwrappers
import math

def show_slices(slices, custom_colourmap=None):
    """ Function to display row of image slices """
    fig, axes = plt.subplots(1, len(slices))
    fig.set_size_inches(48.5, 40.5)

    if custom_colourmap is not None:
        cmap = colors.ListedColormap(custom_colourmap)
    else:
        cmap = 'gray'

    for i, slice in enumerate(slices):
        axes[i].imshow(slice.T, cmap=cmap, interpolation='nearest', origin="lower")
        
def load_and_plot(name, return_array=False):
    """ Load x y and z middle slices of volume and plot efficiently, using nibabel proxy slicing """
    proxy_img = nib.load(name)
    img_shape = proxy_img.shape
    vol1 = proxy_img.dataobj[math.floor(img_shape[0]/2), :, :]
    vol2 = proxy_img.dataobj[:, math.floor(img_shape[1]/2), :]
    vol3 = proxy_img.dataobj[:, :, math.floor(img_shape[2]/2)]
    array = [
        vol1,
        vol2,
        vol3
    ]   
    show_slices(array)
    if return_array:
        return array
    
def load_and_plot_pair(name1, name2, index=0, axis=2, return_array=False):
    """
    Load single axis slice of two volumes and plot efficiently, using nibabel proxy slicing.
    Note, z axis (axis 2) will plot the fastest followed by the y axis (axis 1) due to the way proxy slicing works
    
    """
    proxy_img1 = nib.load(name1)
    proxy_img2 = nib.load(name2)
    if axis == 0:
        vol1 = proxy_img1.dataobj[index, ...] 
        vol2 = proxy_img2.dataobj[index, ...]
    if axis == 1:
        vol1 = proxy_img1.dataobj[:, index, :] 
        vol2 = proxy_img2.dataobj[:, index, :]
    if axis == 2:
        vol1 = proxy_img1.dataobj[..., index] 
        vol2 = proxy_img2.dataobj[..., index]
    array = [
        vol1,
        vol2
    ]   
    show_slices(array)
    if return_array:
        return array

def load_and_plot_stack(name, index_interval=100, axis=2, return_array=False, custom_colourmap=None):
    """
    Load single axis slice of two volumes and plot efficiently, using nibabel proxy slicing.
    Note, z axis (axis 2) will plot the fastest followed by the y axis (axis 1) due to the way proxy slicing works
    
    """
    proxy_img = nib.load(name)

    proxy_img_shape = proxy_img.shape

    array = []
    interval = np.arange(0, proxy_img_shape[axis], index_interval)
    for i in interval:
        if axis == 0:
            vol = proxy_img.dataobj[i, ...] 
        if axis == 1:
            vol = proxy_img.dataobj[:, i, :] 
        if axis == 2:
            vol = proxy_img.dataobj[..., i] 
        array.append(vol)

    show_slices(array, custom_colourmap=custom_colourmap)
    if return_array:
        return array

# %% [markdown]
# Now let's go through each scan and make sure the data points match up correctly.

# %%
scan = 12
name1 = images[scan]
name2 = labels[scan]

print(f'Plotting scan: {name1}')

array = load_and_plot_pair(name1, name2, index=108, axis=2, return_array = True)

print(f'Unique values in label slice are: {np.unique(array[1])}')
print('Red = rhabdoms and White = corneas')
# Out:
# Plotting scan: dataset/images/P_crassipes_FEG190801_034_00001_new.nii
# Unique values in label slice are: [0]
# Red = rhabdoms and White = corneas

# %%
scan = 14
name1 = images[scan]
name2 = labels[scan]

print(f'Plotting scan: {name1}')

array = load_and_plot_stack(name1, index_interval=200, axis=2, return_array = True)
array = load_and_plot_stack(name2, index_interval=200, axis=2, return_array = True, custom_colourmap=['none', 'r', 'g'])
# Out:
# Plotting scan: dataset/images/P_crassipes_FEG191022_077B.nii

# %% [markdown]
# We can also view them in a 3d program (e.g. Dragonfly or 3D Slicer)
