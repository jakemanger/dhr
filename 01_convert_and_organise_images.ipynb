# %% [markdown]
# # Initial setup
# ## Load dependencies

# %%
import os
import numpy as np
from pathlib import Path
import time
from shutil import copyfile

# %% [markdown]
# ## Define locations for data
# We seperate output directories into raw and non-raw/final. This is because we need to do a set of preprocessing stages to the raw data before we make the final dataset.

# %%
# inputs
input_image_dir = '//media/jake/1tb_ssd/mctv_analysis/head_scans'
input_labels_dir = '//media/jake/1tb_ssd/mctv_analysis/mctv_resfiles'

# outputs
main_dir = '//media/jake/data/jake/mctnet_data'
raw_image_dir = '//media/jake/data/jake/mctnet_data/raw_images'
raw_labels_dir = '//media/jake/data/jake/mctnet_data/raw_labels'
image_dir = '//media/jake/data/jake/mctnet_data/images'
labels_dir = '//media/jake/data/jake/mctnet_data/labels'

if not os.path.isdir(image_dir):
    os.makedirs(image_dir)

if not os.path.isdir(labels_dir):
    os.makedirs(labels_dir)

# %% [markdown]
# # Collate images
# Our original images are organised in a messy way. Let's collate them together and fix that up.
#
# First, let's find all the images in the input image directory

# %%
nii_files = []
dicom_dirs = []
for root, dirs, files in os.walk(input_image_dir):
    for i, file in enumerate(files):
        if file.endswith('.nii'):
            nii_files.append(root + '/' + file)
        if file.endswith('.dcm'):
            dicom_dirs.append(root)

# remove duplicate dicom_dirs
dicom_dirs = list(set(dicom_dirs))

print('Found ' + str(len(nii_files)) + ' nifti files')
print('Found ' + str(len(dicom_dirs)) + ' dicom directories')
# Out:
# Found 26 nifti files
# Found 70 dicom directories

# %% [markdown]
# Let's plot the first 10

# %%
nii_files[:10]
# Out:
# ['//media/jake/1tb_ssd/mctv_analysis/head_scans/Brachyscelus.nii',
#  '//media/jake/1tb_ssd/mctv_analysis/head_scans/Vibilia_01_FEG191211_087_filterted.nii',
#  '//media/jake/1tb_ssd/mctv_analysis/head_scans/Paraphronima_FEG200130_103_head_04.nii',
#  '//media/jake/1tb_ssd/mctv_analysis/head_scans/Scypholanceola_head_02_FEG191022_076.nii',
#  '//media/jake/1tb_ssd/mctv_analysis/head_scans/Platyscelus_02_FEG191112_082.nii',
#  '//media/jake/1tb_ssd/mctv_analysis/head_scans/Phronima_05_FEG200107_090.nii',
#  '//media/jake/1tb_ssd/mctv_analysis/head_scans/Paraphronima_FEG200130_102_head_05.nii',
#  '//media/jake/1tb_ssd/mctv_analysis/head_scans/Hyperia 01_segmented eyes.nii',
#  '//media/jake/1tb_ssd/mctv_analysis/head_scans/Phronima_04_FEG200107_089.nii',
#  '//media/jake/1tb_ssd/mctv_analysis/head_scans/psyllid_20190906_male_eye/psyllid_20190906_male_eye.nii']

# %%
dicom_dirs[:10]
# Out:
# ['//media/jake/1tb_ssd/mctv_analysis/head_scans/Paraphronima_head_04_FEG200130_103',
#  '//media/jake/1tb_ssd/mctv_analysis/head_scans/Streetsia_01_head_sp_4_USNM1450785_3',
#  '//media/jake/1tb_ssd/mctv_analysis/head_scans/Eupronoe_03_sp_6_A',
#  '//media/jake/1tb_ssd/mctv_analysis/head_scans/Scina_02_sp_2_1450794_slices',
#  '//media/jake/1tb_ssd/mctv_analysis/head_scans/Paraphronima_FEG181024_head_sp_8_1423158/Paraphronima_sp_8_1423158-slices',
#  '//media/jake/1tb_ssd/mctv_analysis/head_scans/Hyperia_head_7_1432188A',
#  '//media/jake/1tb_ssd/mctv_analysis/head_scans/Cystisoma_FEG190802_040_brain',
#  '//media/jake/1tb_ssd/mctv_analysis/head_scans/Streetsia_head_sp_4_USNM1450785_2',
#  '//media/jake/1tb_ssd/mctv_analysis/head_scans/Streetsia_head_sp_4_USNM1450785_1',
#  '//media/jake/1tb_ssd/mctv_analysis/head_scans/P_crassipes_FEG190213_003b_02_head']

# %% [markdown]
# # Move nifti to raw images folder
# Let's move all the nifti files to the raw_images directory.

# %%
for d in nii_files:
    p = Path(d)
    filename = p.stem
    new_path = raw_image_dir + "/" + filename + '.nii'
    if not os.path.isfile(new_path):
        copyfile(d, new_path)
        print(f'Copied nifti {d} to {new_path}\n')
    else:
        print(f'File {new_path} already exists, so skipped this copy\n')
# Out:
# File //media/jake/data/jake/mctnet_data/raw_images/Brachyscelus.nii already exists, so skipped this copy
#
# File //media/jake/data/jake/mctnet_data/raw_images/Vibilia_01_FEG191211_087_filterted.nii already exists, so skipped this copy
#
# File //media/jake/data/jake/mctnet_data/raw_images/Paraphronima_FEG200130_103_head_04.nii already exists, so skipped this copy
#
# File //media/jake/data/jake/mctnet_data/raw_images/Scypholanceola_head_02_FEG191022_076.nii already exists, so skipped this copy
#
# File //media/jake/data/jake/mctnet_data/raw_images/Platyscelus_02_FEG191112_082.nii already exists, so skipped this copy
#
# File //media/jake/data/jake/mctnet_data/raw_images/Phronima_05_FEG200107_090.nii already exists, so skipped this copy
#
# File //media/jake/data/jake/mctnet_data/raw_images/Paraphronima_FEG200130_102_head_05.nii already exists, so skipped this copy
#
# File //media/jake/data/jake/mctnet_data/raw_images/Hyperia 01_segmented eyes.nii already exists, so skipped this copy
#
# File //media/jake/data/jake/mctnet_data/raw_images/Phronima_04_FEG200107_089.nii already exists, so skipped this copy
#
# File //media/jake/data/jake/mctnet_data/raw_images/psyllid_20190906_male_eye.nii already exists, so skipped this copy
#
# File //media/jake/data/jake/mctnet_data/raw_images/crab-eyestalk_FOV3mm-PIX2.9micron.nii already exists, so skipped this copy
#
# File //media/jake/data/jake/mctnet_data/raw_images/dampieri_male_16.nii already exists, so skipped this copy
#
# File //media/jake/data/jake/mctnet_data/raw_images/diurnal_tarsata.nii already exists, so skipped this copy
#
# File //media/jake/data/jake/mctnet_data/raw_images/flammula_20180307.nii already exists, so skipped this copy
#
# File //media/jake/data/jake/mctnet_data/raw_images/flammula_20190925_male_left.nii already exists, so skipped this copy
#
# File //media/jake/data/jake/mctnet_data/raw_images/flammula_20200327_female_left_178_fullres_cropped.nii already exists, so skipped this copy
#
# File //media/jake/data/jake/mctnet_data/raw_images/neohelice_20190616_1_cropped.nii already exists, so skipped this copy
#
# File //media/jake/data/jake/mctnet_data/raw_images/phronima_20180403.nii already exists, so skipped this copy
#
# File //media/jake/data/jake/mctnet_data/raw_images/psyllid_20190906_female_eye.nii already exists, so skipped this copy
#
# File //media/jake/data/jake/mctnet_data/raw_images/dampieri_20181221_female_left.nii already exists, so skipped this copy
#
# File //media/jake/data/jake/mctnet_data/raw_images/20181221L_female_cropped.nii already exists, so skipped this copy
#
# File //media/jake/data/jake/mctnet_data/raw_images/flammula_female_left_17.nii already exists, so skipped this copy
#
# File //media/jake/data/jake/mctnet_data/raw_images/dampieri_female_18.nii already exists, so skipped this copy
#
# File //media/jake/data/jake/mctnet_data/raw_images/dampieri_female_right_19.nii already exists, so skipped this copy
#
# File //media/jake/data/jake/mctnet_data/raw_images/dampieri_20200218_male_left_1676.nii already exists, so skipped this copy
#
# File //media/jake/data/jake/mctnet_data/raw_images/dampieri_20200218_male_right_1676.nii already exists, so skipped this copy

# %% [markdown]
# # Convert dicom to nifti
# A bunch of files are in the dicom format. Let's convert these to nifti, so that all our data are consistent and in single files.
#
# To do this, we will be using dcm2niix found at https://github.com/rordenlab/dcm2niix
# This can be installed on linux via
# ```
# sudo apt install dicom2nixx
# ```

# %% [markdown]
# We have the dicom directories in `dicom_dirs` but we also need to extract the output path and the filename. Let's do that here

# %%
import pprint

conversion_info = []

for d in dicom_dirs:
    p = Path(d)
    filename = p.stem
    #new_path = raw_image_dir + "/" + filename + '.nii'

    conversion_info.append(
        dict(
            in_dir=d,
            out_dir=raw_image_dir,
            filename=filename
        )
    )

# print first 5 to check if looks ok
pp = pprint.PrettyPrinter(indent=2)
pp.pprint(conversion_info[:5])
# Out:
# [ { 'filename': 'Paraphronima_head_04_FEG200130_103',
#     'in_dir': '//media/jake/1tb_ssd/mctv_analysis/head_scans/Paraphronima_head_04_FEG200130_103',
#     'out_dir': '//media/jake/data/jake/mctnet_data/raw_images'},
#   { 'filename': 'Streetsia_01_head_sp_4_USNM1450785_3',
#     'in_dir': '//media/jake/1tb_ssd/mctv_analysis/head_scans/Streetsia_01_head_sp_4_USNM1450785_3',
#     'out_dir': '//media/jake/data/jake/mctnet_data/raw_images'},
#   { 'filename': 'Eupronoe_03_sp_6_A',
#     'in_dir': '//media/jake/1tb_ssd/mctv_analysis/head_scans/Eupronoe_03_sp_6_A',
#     'out_dir': '//media/jake/data/jake/mctnet_data/raw_images'},
#   { 'filename': 'Scina_02_sp_2_1450794_slices',
#     'in_dir': '//media/jake/1tb_ssd/mctv_analysis/head_scans/Scina_02_sp_2_1450794_slices',
#     'out_dir': '//media/jake/data/jake/mctnet_data/raw_images'},
#   { 'filename': 'Paraphronima_sp_8_1423158-slices',
#     'in_dir': '//media/jake/1tb_ssd/mctv_analysis/head_scans/Paraphronima_FEG181024_head_sp_8_1423158/Paraphronima_sp_8_1423158-slices',
#     'out_dir': '//media/jake/data/jake/mctnet_data/raw_images'}]

# %% [markdown]
# Now let's create a yaml file to tell dicom2niix what to do

# %%
import yaml

data = dict(
    Options = dict(
      isGz='false',
      isFlipY='false',
      isVerbose='false',
      isCreateBIDS='false',
      isOnlySingleFile='false'
    ),
    Files = conversion_info
)
with open('dicom2niix_batch_info.yml', 'w') as outfile:
    yaml.dump(data, outfile)

# %% [markdown]
# and let's run dicom2niix

# %%
# !dcm2niibatch dicom2niix_batch_info.yml
# Out:
# dcm2niibatch using Chris Rorden's dcm2niiX version v1.0.20181125  (JP2:OpenJPEG) GCC9.3.0 (64-bit Linux)
# yaml_path: dicom2niix_batch_info.yml
# Compression will be faster with 'pigz' installed
# Found 1496 DICOM file(s)
# Error: Instance number (0020,0013) not found: //media/jake/1tb_ssd/mctv_analysis/head_scans/Paraphronima_head_04_FEG200130_103/FEG200130_103_0000.dcm
# Error: Instance number (0020,0013) not found: //media/jake/1tb_ssd/mctv_analysis/head_scans/Paraphronima_head_04_FEG200130_103/FEG200130_103_0001.dcm
# Error: Instance number (0020,0013) not found: //media/jake/1tb_ssd/mctv_analysis/head_scans/Paraphronima_head_04_FEG200130_103/FEG200130_103_0002.dcm
# Error: Instance number (0020,0013) not found: //media/jake/1tb_ssd/mctv_analysis/head_scans/Paraphronima_head_04_FEG200130_103/FEG200130_103_0003.dcm
# Error: Instance number (0020,0013) not found: //media/jake/1tb_ssd/mctv_analysis/head_scans/Paraphronima_head_04_FEG200130_103/FEG200130_103_0004.dcm
# Error: Instance number (0020,0013) not found: //media/jake/1tb_ssd/mctv_analysis/head_scans/Paraphronima_head_04_FEG200130_103/FEG200130_103_0005.dcm
# Error: Instance number (0020,0013) not found: //media/jake/1tb_ssd/mctv_analysis/head_scans/Paraphronima_head_04_FEG200130_103/FEG200130_103_0006.dcm
# Error: Instance number (0020,0013) not found: //media/jake/1tb_ssd/mctv_analysis/head_scans/Paraphronima_head_04_FEG200130_103/FEG200130_103_0007.dcm
# Error: Instance number (0020,0013) not found: //media/jake/1tb_ssd/mctv_analysis/head_scans/Paraphronima_head_04_FEG200130_103/FEG200130_103_0008.dcm
# Error: Instance number (0020,0013) not found: //media/jake/1tb_ssd/mctv_analysis/head_scans/Paraphronima_head_04_FEG200130_103/FEG200130_103_0009.dcm
# Error: Instance number (0020,0013) not found: //media/jake/1tb_ssd/mctv_analysis/head_scans/Paraphronima_head_04_FEG200130_103/FEG200130_103_0010.dcm
# Error: Instance number (0020,0013) not found: //media/jake/1tb_ssd/mctv_analysis/head_scans/Paraphronima_head_04_FEG200130_103/FEG200130_103_0011.dcm
# Error: Instance number (0020,0013) not found: //media/jake/1tb_ssd/mctv_analysis/head_scans/Paraphronima_head_04_FEG200130_103/FEG200130_103_0012.dcm
# Error: Instance number (0020,0013) not found: //media/jake/1tb_ssd/mctv_analysis/head_scans/Paraphronima_head_04_FEG200130_103/FEG200130_103_0013.dcm
# Error: Instance number (0020,0013) not found: //media/jake/1tb_ssd/mctv_analysis/head_scans/Paraphronima_head_04_FEG200130_103/FEG200130_103_0014.dcm
# Error: Instance number (0020,0013) not found: //media/jake/1tb_ssd/mctv_analysis/head_scans/Paraphronima_head_04_FEG200130_103/FEG200130_103_0015.dcm
# Error: Instance number (0020,0013) not found: //media/jake/1tb_ssd/mctv_analysis/head_scans/Paraphronima_head_04_FEG200130_103/FEG200130_103_0016.dcm
# Error: Instance number (0020,0013) not found: //media/jake/1tb_ssd/mctv_analysis/head_scans/Paraphronima_head_04_FEG200130_103/FEG200130_103_0017.dcm
# Error: Instance number (0020,0013) not found: //media/jake/1tb_ssd/mctv_analysis/head_scans/Paraphronima_head_04_FEG200130_103/FEG200130_103_0018.dcm
# Error: Instance number (0020,0013) not found: //media/jake/1tb_ssd/mctv_analysis/head_scans/Paraphronima_head_04_FEG200130_103/FEG200130_103_0019.dcm
# Error: Instance number (0020,0013) not found: //media/jake/1tb_ssd/mctv_analysis/head_scans/Paraphronima_head_04_FEG200130_103/FEG200130_103_0020.dcm
# Error: Instance number (0020,0013) not found: //media/jake/1tb_ssd/mctv_analysis/head_scans/Paraphronima_head_04_FEG200130_103/FEG200130_103_0021.dcm
# Error: Instance number (0020,0013) not found: //media/jake/1tb_ssd/mctv_analysis/head_scans/Paraphronima_head_04_FEG200130_103/FEG200130_103_0022.dcm
# Error: Instance number (0020,0013) not found: //media/jake/1tb_ssd/mctv_analysis/head_scans/Paraphronima_head_04_FEG200130_103/FEG200130_103_0023.dcm
# Error: Instance number (0020,0013) not found: //media/jake/1tb_ssd/mctv_analysis/head_scans/Paraphronima_head_04_FEG200130_103/FEG200130_103_0024.dcm
# Error: Instance number (0020,0013) not found: //media/jake/1tb_ssd/mctv_analysis/head_scans/Paraphronima_head_04_FEG200130_103/FEG200130_103_0025.dcm
# Error: Instance number (0020,0013) not found: //media/jake/1tb_ssd/mctv_analysis/head_scans/Paraphronima_head_04_FEG200130_103/FEG200130_103_0026.dcm
# Error: Instance number (0020,0013) not found: //media/jake/1tb_ssd/mctv_analysis/head_scans/Paraphronima_head_04_FEG200130_103/FEG200130_103_0027.dcm
# Error: Instance number (0020,0013) not found: //media/jake/1tb_ssd/mctv_analysis/head_scans/Paraphronima_head_04_FEG200130_103/FEG200130_103_0028.dcm
# Error: Instance number (0020,0013) not found: //media/jake/1tb_ssd/mctv_analysis/head_scans/Paraphronima_head_04_FEG200130_103/FEG200130_103_0029.dcm
# Error: Instance number (0020,0013) not found: //media/jake/1tb_ssd/mctv_analysis/head_scans/Paraphronima_head_04_FEG200130_103/FEG200130_103_0030.dcm
# Error: Instance number (0020,0013) not found: //media/jake/1tb_ssd/mctv_analysis/head_scans/Paraphronima_head_04_FEG200130_103/FEG200130_103_0031.dcm
# Error: Instance number (0020,0013) not found: //media/jake/1tb_ssd/mctv_analysis/head_scans/Paraphronima_head_04_FEG200130_103/FEG200130_103_0032.dcm
# Error: Instance number (0020,0013) not found: //media/jake/1tb_ssd/mctv_analysis/head_scans/Paraphronima_head_04_FEG200130_103/FEG200130_103_0033.dcm
# Error: Instance number (0020,0013) not found: //media/jake/1tb_ssd/mctv_analysis/head_scans/Paraphronima_head_04_FEG200130_103/FEG200130_103_0034.dcm
# Error: Instance number (0020,0013) not found: //media/jake/1tb_ssd/mctv_analysis/head_scans/Paraphronima_head_04_FEG200130_103/FEG200130_103_0035.dcm
# Error: Instance number (0020,0013) not found: //media/jake/1tb_ssd/mctv_analysis/head_scans/Paraphronima_head_04_FEG200130_103/FEG200130_103_0036.dcm
# Error: Instance number (0020,0013) not found: //media/jake/1tb_ssd/mctv_analysis/head_scans/Paraphronima_head_04_FEG200130_103/FEG200130_103_0037.dcm
# Error: Instance number (0020,0013) not found: //media/jake/1tb_ssd/mctv_analysis/head_scans/Paraphronima_head_04_FEG200130_103/FEG200130_103_0038.dcm
# Error: Instance number (0020,0013) not found: //media/jake/1tb_ssd/mctv_analysis/head_scans/Paraphronima_head_04_FEG200130_103/FEG200130_103_0039.dcm
# Error: Instance number (0020,0013) not found: //media/jake/1tb_ssd/mctv_analysis/head_scans/Paraphronima_head_04_FEG200130_103/FEG200130_103_0040.dcm
# Error: Instance number (0020,0013) not found: //media/jake/1tb_ssd/mctv_analysis/head_scans/Paraphronima_head_04_FEG200130_103/FEG200130_103_0041.dcm
# Error: Instance number (0020,0013) not found: //media/jake/1tb_ssd/mctv_analysis/head_scans/Paraphronima_head_04_FEG200130_103/FEG200130_103_0042.dcm
# Error: Instance number (0020,0013) not found: //media/jake/1tb_ssd/mctv_analysis/head_scans/Paraphronima_head_04_FEG200130_103/FEG200130_103_0043.dcm
# Error: Instance number (0020,0013) not found: //media/jake/1tb_ssd/mctv_analysis/head_scans/Paraphronima_head_04_FEG200130_103/FEG200130_103_0044.dcm
# Error: Instance number (0020,0013) not found: //media/jake/1tb_ssd/mctv_analysis/head_scans/Paraphronima_head_04_FEG200130_103/FEG200130_103_0045.dcm
# Error: Instance number (0020,0013) not found: //media/jake/1tb_ssd/mctv_analysis/head_scans/Paraphronima_head_04_FEG200130_103/FEG200130_103_0046.dcm
# Error: Instance number (0020,0013) not found: //media/jake/1tb_ssd/mctv_analysis/head_scans/Paraphronima_head_04_FEG200130_103/FEG200130_103_0047.dcm
# Error: Instance number (0020,0013) not found: //media/jake/1tb_ssd/mctv_analysis/head_scans/Paraphronima_head_04_FEG200130_103/FEG200130_103_0048.dcm
# Error: Instance number (0020,0013) not found: //media/jake/1tb_ssd/mctv_analysis/head_scans/Paraphronima_head_04_FEG200130_103/FEG200130_103_0049.dcm
# Error: Instance number (0020,0013) not found: //media/jake/1tb_ssd/mctv_analysis/head_scans/Paraphronima_head_04_FEG200130_103/FEG200130_103_0050.dcm
# Error: Instance number (0020,0013) not found: //media/jake/1tb_ssd/mctv_analysis/head_scans/Paraphronima_head_04_FEG200130_103/FEG200130_103_0051.dcm
# Error: Instance number (0020,0013) not found: //media/jake/1tb_ssd/mctv_analysis/head_scans/Paraphronima_head_04_FEG200130_103/FEG200130_103_0052.dcm
# Error: Instance number (0020,0013) not found: //media/jake/1tb_ssd/mctv_analysis/head_scans/Paraphronima_head_04_FEG200130_103/FEG200130_103_0053.dcm
# Error: Instance number (0020,0013) not found: //media/jake/1tb_ssd/mctv_analysis/head_scans/Paraphronima_head_04_FEG200130_103/FEG200130_103_0054.dcm
# Error: Instance number (0020,0013) not found: //media/jake/1tb_ssd/mctv_analysis/head_scans/Paraphronima_head_04_FEG200130_103/FEG200130_103_0055.dcm
# Error: Instance number (0020,0013) not found: //media/jake/1tb_ssd/mctv_analysis/head_scans/Paraphronima_head_04_FEG200130_103/FEG200130_103_0056.dcm
# Error: Instance number (0020,0013) not found: //media/jake/1tb_ssd/mctv_analysis/head_scans/Paraphronima_head_04_FEG200130_103/FEG200130_103_0057.dcm
# Error: Instance number (0020,0013) not found: //media/jake/1tb_ssd/mctv_analysis/head_scans/Paraphronima_head_04_FEG200130_103/FEG200130_103_0058.dcm
# Error: Instance number (0020,0013) not found: //media/jake/1tb_ssd/mctv_analysis/head_scans/Paraphronima_head_04_FEG200130_103/FEG200130_103_0059.dcm
# Error: Instance number (0020,0013) not found: //media/jake/1tb_ssd/mctv_analysis/head_scans/Paraphronima_head_04_FEG200130_103/FEG200130_103_0060.dcm
# Error: Instance number (0020,0013) not found: //media/jake/1tb_ssd/mctv_analysis/head_scans/Paraphronima_head_04_FEG200130_103/FEG200130_103_0061.dcm
# Error: Instance number (0020,0013) not found: //media/jake/1tb_ssd/mctv_analysis/head_scans/Paraphronima_head_04_FEG200130_103/FEG200130_103_0062.dcm
# Error: Instance number (0020,0013) not found: //media/jake/1tb_ssd/mctv_analysis/head_scans/Paraphronima_head_04_FEG200130_103/FEG200130_103_0063.dcm
# Error: Instance number (0020,0013) not found: //media/jake/1tb_ssd/mctv_analysis/head_scans/Paraphronima_head_04_FEG200130_103/FEG200130_103_0064.dcm
# Error: Instance number (0020,0013) not found: //media/jake/1tb_ssd/mctv_analysis/head_scans/Paraphronima_head_04_FEG200130_103/FEG200130_103_0065.dcm
# Error: Instance number (0020,0013) not found: //media/jake/1tb_ssd/mctv_analysis/head_scans/Paraphronima_head_04_FEG200130_103/FEG200130_103_0066.dcm
# Error: Instance number (0020,0013) not found: //media/jake/1tb_ssd/mctv_analysis/head_scans/Paraphronima_head_04_FEG200130_103/FEG200130_103_0067.dcm
# Error: Instance number (0020,0013) not found: //media/jake/1tb_ssd/mctv_analysis/head_scans/Paraphronima_head_04_FEG200130_103/FEG200130_103_0068.dcm
# Error: Instance number (0020,0013) not found: //media/jake/1tb_ssd/mctv_analysis/head_scans/Paraphronima_head_04_FEG200130_103/FEG200130_103_0069.dcm
# Error: Instance number (0020,0013) not found: //media/jake/1tb_ssd/mctv_analysis/head_scans/Paraphronima_head_04_FEG200130_103/FEG200130_103_0070.dcm
# Error: Instance number (0020,0013) not found: //media/jake/1tb_ssd/mctv_analysis/head_scans/Paraphronima_head_04_FEG200130_103/FEG200130_103_0071.dcm
# Error: Instance number (0020,0013) not found: //media/jake/1tb_ssd/mctv_analysis/head_scans/Paraphronima_head_04_FEG200130_103/FEG200130_103_0072.dcm
# Error: Instance number (0020,0013) not found: //media/jake/1tb_ssd/mctv_analysis/head_scans/Paraphronima_head_04_FEG200130_103/FEG200130_103_0073.dcm
# Error: Instance number (0020,0013) not found: //media/jake/1tb_ssd/mctv_analysis/head_scans/Paraphronima_head_04_FEG200130_103/FEG200130_103_0074.dcm
# Error: Instance number (0020,0013) not found: //media/jake/1tb_ssd/mctv_analysis/head_scans/Paraphronima_head_04_FEG200130_103/FEG200130_103_0075.dcm
# Error: Instance number (0020,0013) not found: //media/jake/1tb_ssd/mctv_analysis/head_scans/Paraphronima_head_04_FEG200130_103/FEG200130_103_0076.dcm
# Error: Instance number (0020,0013) not found: //media/jake/1tb_ssd/mctv_analysis/head_scans/Paraphronima_head_04_FEG200130_103/FEG200130_103_0077.dcm
# Error: Instance number (0020,0013) not found: //media/jake/1tb_ssd/mctv_analysis/head_scans/Paraphronima_head_04_FEG200130_103/FEG200130_103_0078.dcm
# Error: Instance number (0020,0013) not found: //media/jake/1tb_ssd/mctv_analysis/head_scans/Paraphronima_head_04_FEG200130_103/FEG200130_103_0079.dcm
# Error: Instance number (0020,0013) not found: //media/jake/1tb_ssd/mctv_analysis/head_scans/Paraphronima_head_04_FEG200130_103/FEG200130_103_0080.dcm
# Error: Instance number (0020,0013) not found: //media/jake/1tb_ssd/mctv_analysis/head_scans/Paraphronima_head_04_FEG200130_103/FEG200130_103_0081.dcm
# Error: Instance number (0020,0013) not found: //media/jake/1tb_ssd/mctv_analysis/head_scans/Paraphronima_head_04_FEG200130_103/FEG200130_103_0082.dcm
# Error: Instance number (0020,0013) not found: //media/jake/1tb_ssd/mctv_analysis/head_scans/Paraphronima_head_04_FEG200130_103/FEG200130_103_0083.dcm
# Error: Instance number (0020,0013) not found: //media/jake/1tb_ssd/mctv_analysis/head_scans/Paraphronima_head_04_FEG200130_103/FEG200130_103_0084.dcm
# Error: Instance number (0020,0013) not found: //media/jake/1tb_ssd/mctv_analysis/head_scans/Paraphronima_head_04_FEG200130_103/FEG200130_103_0085.dcm
# Error: Instance number (0020,0013) not found: //media/jake/1tb_ssd/mctv_analysis/head_scans/Paraphronima_head_04_FEG200130_103/FEG200130_103_0086.dcm
# Error: Instance number (0020,0013) not found: //media/jake/1tb_ssd/mctv_analysis/head_scans/Paraphronima_head_04_FEG200130_103/FEG200130_103_0087.dcm
# Error: Instance number (0020,0013) not found: //media/jake/1tb_ssd/mctv_analysis/head_scans/Paraphronima_head_04_FEG200130_103/FEG200130_103_0088.dcm
# Error: Instance number (0020,0013) not found: //media/jake/1tb_ssd/mctv_analysis/head_scans/Paraphronima_head_04_FEG200130_103/FEG200130_103_0089.dcm
# Error: Instance number (0020,0013) not found: //media/jake/1tb_ssd/mctv_analysis/head_scans/Paraphronima_head_04_FEG200130_103/FEG200130_103_0090.dcm
# Error: Instance number (0020,0013) not found: //media/jake/1tb_ssd/mctv_analysis/head_scans/Paraphronima_head_04_FEG200130_103/FEG200130_103_0091.dcm
# Error: Instance number (0020,0013) not found: //media/jake/1tb_ssd/mctv_analysis/head_scans/Paraphronima_head_04_FEG200130_103/FEG200130_103_0092.dcm
# Error: Instance number (0020,0013) not found: //media/jake/1tb_ssd/mctv_analysis/head_scans/Paraphronima_head_04_FEG200130_103/FEG200130_103_0093.dcm
# Error: Instance number (0020,0013) not found: //media/jake/1tb_ssd/mctv_analysis/head_scans/Paraphronima_head_04_FEG200130_103/FEG200130_103_0094.dcm
# Error: Instance number (0020,0013) not found: //media/jake/1tb_ssd/mctv_analysis/head_scans/Paraphronima_head_04_FEG200130_103/FEG200130_103_0095.dcm
# Error: Instance number (0020,0013) not found: //media/jake/1tb_ssd/mctv_analysis/head_scans/Paraphronima_head_04_FEG200130_103/FEG200130_103_0096.dcm
# Error: Instance number (0020,0013) not found: //media/jake/1tb_ssd/mctv_analysis/head_scans/Paraphronima_head_04_FEG200130_103/FEG200130_103_0097.dcm
# Error: Instance number (0020,0013) not found: //media/jake/1tb_ssd/mctv_analysis/head_scans/Paraphronima_head_04_FEG200130_103/FEG200130_103_0098.dcm
# Error: Instance number (0020,0013) not found: //media/jake/1tb_ssd/mctv_analysis/head_scans/Paraphronima_head_04_FEG200130_103/FEG200130_103_0099.dcm
# Error: Instance number (0020,0013) not found: //media/jake/1tb_ssd/mctv_analysis/head_scans/Paraphronima_head_04_FEG200130_103/FEG200130_103_0100.dcm
# Error: Instance number (0020,0013) not found: //media/jake/1tb_ssd/mctv_analysis/head_scans/Paraphronima_head_04_FEG200130_103/FEG200130_103_0101.dcm
# Error: Instance number (0020,0013) not found: //media/jake/1tb_ssd/mctv_analysis/head_scans/Paraphronima_head_04_FEG200130_103/FEG200130_103_0102.dcm
# Error: Instance number (0020,0013) not found: //media/jake/1tb_ssd/mctv_analysis/head_scans/Paraphronima_head_04_FEG200130_103/FEG200130_103_0103.dcm
# Error: Instance number (0020,0013) not found: //media/jake/1tb_ssd/mctv_analysis/head_scans/Paraphronima_head_04_FEG200130_103/FEG200130_103_0104.dcm
# Error: Instance number (0020,0013) not found: //media/jake/1tb_ssd/mctv_analysis/head_scans/Paraphronima_head_04_FEG200130_103/FEG200130_103_0105.dcm
# Error: Instance number (0020,0013) not found: //media/jake/1tb_ssd/mctv_analysis/head_scans/Paraphronima_head_04_FEG200130_103/FEG200130_103_0106.dcm
# Error: Instance number (0020,0013) not found: //media/jake/1tb_ssd/mctv_analysis/head_scans/Paraphronima_head_04_FEG200130_103/FEG200130_103_0107.dcm
# Error: Instance number (0020,0013) not found: //media/jake/1tb_ssd/mctv_analysis/head_scans/Paraphronima_head_04_FEG200130_103/FEG200130_103_0108.dcm
# Error: Instance number (0020,0013) not found: //media/jake/1tb_ssd/mctv_analysis/head_scans/Paraphronima_head_04_FEG200130_103/FEG200130_103_0109.dcm
# Error: Instance number (0020,0013) not found: //media/jake/1tb_ssd/mctv_analysis/head_scans/Paraphronima_head_04_FEG200130_103/FEG200130_103_0110.dcm
# Error: Instance number (0020,0013) not found: //media/jake/1tb_ssd/mctv_analysis/head_scans/Paraphronima_head_04_FEG200130_103/FEG200130_103_0111.dcm
# Error: Instance number (0020,0013) not found: //media/jake/1tb_ssd/mctv_analysis/head_scans/Paraphronima_head_04_FEG200130_103/FEG200130_103_0112.dcm
# Error: Instance number (0020,0013) not found: //media/jake/1tb_ssd/mctv_analysis/head_scans/Paraphronima_head_04_FEG200130_103/FEG200130_103_0113.dcm
# Error: Instance number (0020,0013) not found: //media/jake/1tb_ssd/mctv_analysis/head_scans/Paraphronima_head_04_FEG200130_103/FEG200130_103_0114.dcm
# Error: Instance number (0020,0013) not found: //media/jake/1tb_ssd/mctv_analysis/head_scans/Paraphronima_head_04_FEG200130_103/FEG200130_103_0115.dcm
# Error: Instance number (0020,0013) not found: //media/jake/1tb_ssd/mctv_analysis/head_scans/Paraphronima_head_04_FEG200130_103/FEG200130_103_0116.dcm
# Error: Instance number (0020,0013) not found: //media/jake/1tb_ssd/mctv_analysis/head_scans/Paraphronima_head_04_FEG200130_103/FEG200130_103_0117.dcm
# Error: Instance number (0020,0013) not found: //media/jake/1tb_ssd/mctv_analysis/head_scans/Paraphronima_head_04_FEG200130_103/FEG200130_103_0118.dcm
# Error: Instance number (0020,0013) not found: //media/jake/1tb_ssd/mctv_analysis/head_scans/Paraphronima_head_04_FEG200130_103/FEG200130_103_0119.dcm
# Error: Instance number (0020,0013) not found: //media/jake/1tb_ssd/mctv_analysis/head_scans/Paraphronima_head_04_FEG200130_103/FEG200130_103_0120.dcm
# Error: Instance number (0020,0013) not found: //media/jake/1tb_ssd/mctv_analysis/head_scans/Paraphronima_head_04_FEG200130_103/FEG200130_103_0121.dcm
# Error: Instance number (0020,0013) not found: //media/jake/1tb_ssd/mctv_analysis/head_scans/Paraphronima_head_04_FEG200130_103/FEG200130_103_0122.dcm
# Error: Instance number (0020,0013) not found: //media/jake/1tb_ssd/mctv_analysis/head_scans/Paraphronima_head_04_FEG200130_103/FEG200130_103_0123.dcm
# Error: Instance number (0020,0013) not found: //media/jake/1tb_ssd/mctv_analysis/head_scans/Paraphronima_head_04_FEG200130_103/FEG200130_103_0124.dcm
# Error: Instance number (0020,0013) not found: //media/jake/1tb_ssd/mctv_analysis/head_scans/Paraphronima_head_04_FEG200130_103/FEG200130_103_0125.dcm
# Error: Instance number (0020,0013) not found: //media/jake/1tb_ssd/mctv_analysis/head_scans/Paraphronima_head_04_FEG200130_103/FEG200130_103_0126.dcm
# Error: Instance number (0020,0013) not found: //media/jake/1tb_ssd/mctv_analysis/head_scans/Paraphronima_head_04_FEG200130_103/FEG200130_103_0127.dcm
# Error: Instance number (0020,0013) not found: //media/jake/1tb_ssd/mctv_analysis/head_scans/Paraphronima_head_04_FEG200130_103/FEG200130_103_0128.dcm
# Error: Instance number (0020,0013) not found: //media/jake/1tb_ssd/mctv_analysis/head_scans/Paraphronima_head_04_FEG200130_103/FEG200130_103_0129.dcm
# Error: Instance number (0020,0013) not found: //media/jake/1tb_ssd/mctv_analysis/head_scans/Paraphronima_head_04_FEG200130_103/FEG200130_103_0130.dcm
# Error: Instance number (0020,0013) not found: //media/jake/1tb_ssd/mctv_analysis/head_scans/Paraphronima_head_04_FEG200130_103/FEG200130_103_0131.dcm
# Error: Instance number (0020,0013) not found: //media/jake/1tb_ssd/mctv_analysis/head_scans/Paraphronima_head_04_FEG200130_103/FEG200130_103_0132.dcm
# Error: Instance number (0020,0013) not found: //media/jake/1tb_ssd/mctv_analysis/head_scans/Paraphronima_head_04_FEG200130_103/FEG200130_103_0133.dcm
# Error: Instance number (0020,0013) not found: //media/jake/1tb_ssd/mctv_analysis/head_scans/Paraphronima_head_04_FEG200130_103/FEG200130_103_0134.dcm
# Error: Instance number (0020,0013) not found: //media/jake/1tb_ssd/mctv_analysis/head_scans/Paraphronima_head_04_FEG200130_103/FEG200130_103_0135.dcm
# Error: Instance number (0020,0013) not found: //media/jake/1tb_ssd/mctv_analysis/head_scans/Paraphronima_head_04_FEG200130_103/FEG200130_103_0136.dcm
# Error: Instance number (0020,0013) not found: //media/jake/1tb_ssd/mctv_analysis/head_scans/Paraphronima_head_04_FEG200130_103/FEG200130_103_0137.dcm
# Error: Instance number (0020,0013) not found: //media/jake/1tb_ssd/mctv_analysis/head_scans/Paraphronima_head_04_FEG200130_103/FEG200130_103_0138.dcm
# Error: Instance number (0020,0013) not found: //media/jake/1tb_ssd/mctv_analysis/head_scans/Paraphronima_head_04_FEG200130_103/FEG200130_103_0139.dcm
# Error: Instance number (0020,0013) not found: //media/jake/1tb_ssd/mctv_analysis/head_scans/Paraphronima_head_04_FEG200130_103/FEG200130_103_0140.dcm
# Error: Instance number (0020,0013) not found: //media/jake/1tb_ssd/mctv_analysis/head_scans/Paraphronima_head_04_FEG200130_103/FEG200130_103_0141.dcm
# Error: Instance number (0020,0013) not found: //media/jake/1tb_ssd/mctv_analysis/head_scans/Paraphronima_head_04_FEG200130_103/FEG200130_103_0142.dcm
# Error: Instance number (0020,0013) not found: //media/jake/1tb_ssd/mctv_analysis/head_scans/Paraphronima_head_04_FEG200130_103/FEG200130_103_0143.dcm
# Error: Instance number (0020,0013) not found: //media/jake/1tb_ssd/mctv_analysis/head_scans/Paraphronima_head_04_FEG200130_103/FEG200130_103_0144.dcm
# Error: Instance number (0020,0013) not found: //media/jake/1tb_ssd/mctv_analysis/head_scans/Paraphronima_head_04_FEG200130_103/FEG200130_103_0145.dcm
# Error: Instance number (0020,0013) not found: //media/jake/1tb_ssd/mctv_analysis/head_scans/Paraphronima_head_04_FEG200130_103/FEG200130_103_0146.dcm
# Error: Instance number (0020,0013) not found: //media/jake/1tb_ssd/mctv_analysis/head_scans/Paraphronima_head_04_FEG200130_103/FEG200130_103_0147.dcm
# Error: Instance number (0020,0013) not found: //media/jake/1tb_ssd/mctv_analysis/head_scans/Paraphronima_head_04_FEG200130_103/FEG200130_103_0148.dcm
# Error: Instance number (0020,0013) not found: //media/jake/1tb_ssd/mctv_analysis/head_scans/Paraphronima_head_04_FEG200130_103/FEG200130_103_0149.dcm
# Error: Instance number (0020,0013) not found: //media/jake/1tb_ssd/mctv_analysis/head_scans/Paraphronima_head_04_FEG200130_103/FEG200130_103_0150.dcm
# Error: Instance number (0020,0013) not found: //media/jake/1tb_ssd/mctv_analysis/head_scans/Paraphronima_head_04_FEG200130_103/FEG200130_103_0151.dcm
# Error: Instance number (0020,0013) not found: //media/jake/1tb_ssd/mctv_analysis/head_scans/Paraphronima_head_04_FEG200130_103/FEG200130_103_0152.dcm
# Error: Instance number (0020,0013) not found: //media/jake/1tb_ssd/mctv_analysis/head_scans/Paraphronima_head_04_FEG200130_103/FEG200130_103_0153.dcm
# Error: Instance number (0020,0013) not found: //media/jake/1tb_ssd/mctv_analysis/head_scans/Paraphronima_head_04_FEG200130_103/FEG200130_103_0154.dcm
# Error: Instance number (0020,0013) not found: //media/jake/1tb_ssd/mctv_analysis/head_scans/Paraphronima_head_04_FEG200130_103/FEG200130_103_0155.dcm
# Error: Instance number (0020,0013) not found: //media/jake/1tb_ssd/mctv_analysis/head_scans/Paraphronima_head_04_FEG200130_103/FEG200130_103_0156.dcm
# Error: Instance number (0020,0013) not found: //media/jake/1tb_ssd/mctv_analysis/head_scans/Paraphronima_head_04_FEG200130_103/FEG200130_103_0157.dcm
# Error: Instance number (0020,0013) not found: //media/jake/1tb_ssd/mctv_analysis/head_scans/Paraphronima_head_04_FEG200130_103/FEG200130_103_0158.dcm
# Error: Instance number (0020,0013) not found: //media/jake/1tb_ssd/mctv_analysis/head_scans/Paraphronima_head_04_FEG200130_103/FEG200130_103_0159.dcm
# Error: Instance number (0020,0013) not found: //media/jake/1tb_ssd/mctv_analysis/head_scans/Paraphronima_head_04_FEG200130_103/FEG200130_103_0160.dcm
# Error: Instance number (0020,0013) not found: //media/jake/1tb_ssd/mctv_analysis/head_scans/Paraphronima_head_04_FEG200130_103/FEG200130_103_0161.dcm
# Error: Instance number (0020,0013) not found: //media/jake/1tb_ssd/mctv_analysis/head_scans/Paraphronima_head_04_FEG200130_103/FEG200130_103_0162.dcm
# Error: Instance number (0020,0013) not found: //media/jake/1tb_ssd/mctv_analysis/head_scans/Paraphronima_head_04_FEG200130_103/FEG200130_103_0163.dcm
# Error: Instance number (0020,0013) not found: //media/jake/1tb_ssd/mctv_analysis/head_scans/Paraphronima_head_04_FEG200130_103/FEG200130_103_0164.dcm
# Error: Instance number (0020,0013) not found: //media/jake/1tb_ssd/mctv_analysis/head_scans/Paraphronima_head_04_FEG200130_103/FEG200130_103_0165.dcm
# Error: Instance number (0020,0013) not found: //media/jake/1tb_ssd/mctv_analysis/head_scans/Paraphronima_head_04_FEG200130_103/FEG200130_103_0166.dcm
# Error: Instance number (0020,0013) not found: //media/jake/1tb_ssd/mctv_analysis/head_scans/Paraphronima_head_04_FEG200130_103/FEG200130_103_0167.dcm
# Error: Instance number (0020,0013) not found: //media/jake/1tb_ssd/mctv_analysis/head_scans/Paraphronima_head_04_FEG200130_103/FEG200130_103_0168.dcm
# Error: Instance number (0020,0013) not found: //media/jake/1tb_ssd/mctv_analysis/head_scans/Paraphronima_head_04_FEG200130_103/FEG200130_103_0169.dcm
# Error: Instance number (0020,0013) not found: //media/jake/1tb_ssd/mctv_analysis/head_scans/Paraphronima_head_04_FEG200130_103/FEG200130_103_0170.dcm
# Error: Instance number (0020,0013) not found: //media/jake/1tb_ssd/mctv_analysis/head_scans/Paraphronima_head_04_FEG200130_103/FEG200130_103_0171.dcm
# Error: Instance number (0020,0013) not found: //media/jake/1tb_ssd/mctv_analysis/head_scans/Paraphronima_head_04_FEG200130_103/FEG200130_103_0172.dcm
# Error: Instance number (0020,0013) not found: //media/jake/1tb_ssd/mctv_analysis/head_scans/Paraphronima_head_04_FEG200130_103/FEG200130_103_0173.dcm
# Error: Instance number (0020,0013) not found: //media/jake/1tb_ssd/mctv_analysis/head_scans/Paraphronima_head_04_FEG200130_103/FEG200130_103_0174.dcm
# Error: Instance number (0020,0013) not found: //media/jake/1tb_ssd/mctv_analysis/head_scans/Paraphronima_head_04_FEG200130_103/FEG200130_103_0175.dcm
# Error: Instance number (0020,0013) not found: //media/jake/1tb_ssd/mctv_analysis/head_scans/Paraphronima_head_04_FEG200130_103/FEG200130_103_0176.dcm
# Error: Instance number (0020,0013) not found: //media/jake/1tb_ssd/mctv_analysis/head_scans/Paraphronima_head_04_FEG200130_103/FEG200130_103_0177.dcm
# Error: Instance number (0020,0013) not found: //media/jake/1tb_ssd/mctv_analysis/head_scans/Paraphronima_head_04_FEG200130_103/FEG200130_103_0178.dcm
# Error: Instance number (0020,0013) not found: //media/jake/1tb_ssd/mctv_analysis/head_scans/Paraphronima_head_04_FEG200130_103/FEG200130_103_0179.dcm
# Error: Instance number (0020,0013) not found: //media/jake/1tb_ssd/mctv_analysis/head_scans/Paraphronima_head_04_FEG200130_103/FEG200130_103_0180.dcm
# Error: Instance number (0020,0013) not found: //media/jake/1tb_ssd/mctv_analysis/head_scans/Paraphronima_head_04_FEG200130_103/FEG200130_103_0181.dcm
# Error: Instance number (0020,0013) not found: //media/jake/1tb_ssd/mctv_analysis/head_scans/Paraphronima_head_04_FEG200130_103/FEG200130_103_0182.dcm
# Error: Instance number (0020,0013) not found: //media/jake/1tb_ssd/mctv_analysis/head_scans/Paraphronima_head_04_FEG200130_103/FEG200130_103_0183.dcm
# Error: Instance number (0020,0013) not found: //media/jake/1tb_ssd/mctv_analysis/head_scans/Paraphronima_head_04_FEG200130_103/FEG200130_103_0184.dcm
# Error: Instance number (0020,0013) not found: //media/jake/1tb_ssd/mctv_analysis/head_scans/Paraphronima_head_04_FEG200130_103/FEG200130_103_0185.dcm
# Error: Instance number (0020,0013) not found: //media/jake/1tb_ssd/mctv_analysis/head_scans/Paraphronima_head_04_FEG200130_103/FEG200130_103_0186.dcm
# Error: Instance number (0020,0013) not found: //media/jake/1tb_ssd/mctv_analysis/head_scans/Paraphronima_head_04_FEG200130_103/FEG200130_103_0187.dcm
# Error: Instance number (0020,0013) not found: //media/jake/1tb_ssd/mctv_analysis/head_scans/Paraphronima_head_04_FEG200130_103/FEG200130_103_0188.dcm
# Error: Instance number (0020,0013) not found: //media/jake/1tb_ssd/mctv_analysis/head_scans/Paraphronima_head_04_FEG200130_103/FEG200130_103_0189.dcm
# Error: Instance number (0020,0013) not found: //media/jake/1tb_ssd/mctv_analysis/head_scans/Paraphronima_head_04_FEG200130_103/FEG200130_103_0190.dcm
# Error: Instance number (0020,0013) not found: //media/jake/1tb_ssd/mctv_analysis/head_scans/Paraphronima_head_04_FEG200130_103/FEG200130_103_0191.dcm
# Error: Instance number (0020,0013) not found: //media/jake/1tb_ssd/mctv_analysis/head_scans/Paraphronima_head_04_FEG200130_103/FEG200130_103_0192.dcm
# Error: Instance number (0020,0013) not found: //media/jake/1tb_ssd/mctv_analysis/head_scans/Paraphronima_head_04_FEG200130_103/FEG200130_103_0193.dcm
# Error: Instance number (0020,0013) not found: //media/jake/1tb_ssd/mctv_analysis/head_scans/Paraphronima_head_04_FEG200130_103/FEG200130_103_0194.dcm
# Error: Instance number (0020,0013) not found: //media/jake/1tb_ssd/mctv_analysis/head_scans/Paraphronima_head_04_FEG200130_103/FEG200130_103_0195.dcm
# Error: Instance number (0020,0013) not found: //media/jake/1tb_ssd/mctv_analysis/head_scans/Paraphronima_head_04_FEG200130_103/FEG200130_103_0196.dcm
# Error: Instance number (0020,0013) not found: //media/jake/1tb_ssd/mctv_analysis/head_scans/Paraphronima_head_04_FEG200130_103/FEG200130_103_0197.dcm
# Error: Instance number (0020,0013) not found: //media/jake/1tb_ssd/mctv_analysis/head_scans/Paraphronima_head_04_FEG200130_103/FEG200130_103_0198.dcm
# Error: Instance number (0020,0013) not found: //media/jake/1tb_ssd/mctv_analysis/head_scans/Paraphronima_head_04_FEG200130_103/FEG200130_103_0199.dcm
# Error: Instance number (0020,0013) not found: //media/jake/1tb_ssd/mctv_analysis/head_scans/Paraphronima_head_04_FEG200130_103/FEG200130_103_0200.dcm
# Error: Instance number (0020,0013) not found: //media/jake/1tb_ssd/mctv_analysis/head_scans/Paraphronima_head_04_FEG200130_103/FEG200130_103_0201.dcm
# Error: Instance number (0020,0013) not found: //media/jake/1tb_ssd/mctv_analysis/head_scans/Paraphronima_head_04_FEG200130_103/FEG200130_103_0202.dcm
# Error: Instance number (0020,0013) not found: //media/jake/1tb_ssd/mctv_analysis/head_scans/Paraphronima_head_04_FEG200130_103/FEG200130_103_0203.dcm
# Error: Instance number (0020,0013) not found: //media/jake/1tb_ssd/mctv_analysis/head_scans/Paraphronima_head_04_FEG200130_103/FEG200130_103_0204.dcm
# Error: Instance number (0020,0013) not found: //media/jake/1tb_ssd/mctv_analysis/head_scans/Paraphronima_head_04_FEG200130_103/FEG200130_103_0205.dcm
# Error: Instance number (0020,0013) not found: //media/jake/1tb_ssd/mctv_analysis/head_scans/Paraphronima_head_04_FEG200130_103/FEG200130_103_0206.dcm
# Error: Instance number (0020,0013) not found: //media/jake/1tb_ssd/mctv_analysis/head_scans/Paraphronima_head_04_FEG200130_103/FEG200130_103_0207.dcm
# Error: Instance number (0020,0013) not found: //media/jake/1tb_ssd/mctv_analysis/head_scans/Paraphronima_head_04_FEG200130_103/FEG200130_103_0208.dcm
# Error: Instance number (0020,0013) not found: //media/jake/1tb_ssd/mctv_analysis/head_scans/Paraphronima_head_04_FEG200130_103/FEG200130_103_0209.dcm
# Error: Instance number (0020,0013) not found: //media/jake/1tb_ssd/mctv_analysis/head_scans/Paraphronima_head_04_FEG200130_103/FEG200130_103_0210.dcm
# Error: Instance number (0020,0013) not found: //media/jake/1tb_ssd/mctv_analysis/head_scans/Paraphronima_head_04_FEG200130_103/FEG200130_103_0211.dcm
# Error: Instance number (0020,0013) not found: //media/jake/1tb_ssd/mctv_analysis/head_scans/Paraphronima_head_04_FEG200130_103/FEG200130_103_0212.dcm
# Error: Instance number (0020,0013) not found: //media/jake/1tb_ssd/mctv_analysis/head_scans/Paraphronima_head_04_FEG200130_103/FEG200130_103_0213.dcm
# Error: Instance number (0020,0013) not found: //media/jake/1tb_ssd/mctv_analysis/head_scans/Paraphronima_head_04_FEG200130_103/FEG200130_103_0214.dcm
# Error: Instance number (0020,0013) not found: //media/jake/1tb_ssd/mctv_analysis/head_scans/Paraphronima_head_04_FEG200130_103/FEG200130_103_0215.dcm
# Error: Instance number (0020,0013) not found: //media/jake/1tb_ssd/mctv_analysis/head_scans/Paraphronima_head_04_FEG200130_103/FEG200130_103_0216.dcm
# Error: Instance number (0020,0013) not found: //media/jake/1tb_ssd/mctv_analysis/head_scans/Paraphronima_head_04_FEG200130_103/FEG200130_103_0217.dcm
# Error: Instance number (0020,0013) not found: //media/jake/1tb_ssd/mctv_analysis/head_scans/Paraphronima_head_04_FEG200130_103/FEG200130_103_0218.dcm
# Error: Instance number (0020,0013) not found: //media/jake/1tb_ssd/mctv_analysis/head_scans/Paraphronima_head_04_FEG200130_103/FEG200130_103_0219.dcm
# Error: Instance number (0020,0013) not found: //media/jake/1tb_ssd/mctv_analysis/head_scans/Paraphronima_head_04_FEG200130_103/FEG200130_103_0220.dcm
# Error: Instance number (0020,0013) not found: //media/jake/1tb_ssd/mctv_analysis/head_scans/Paraphronima_head_04_FEG200130_103/FEG200130_103_0221.dcm
# Error: Instance number (0020,0013) not found: //media/jake/1tb_ssd/mctv_analysis/head_scans/Paraphronima_head_04_FEG200130_103/FEG200130_103_0222.dcm
# Error: Instance number (0020,0013) not found: //media/jake/1tb_ssd/mctv_analysis/head_scans/Paraphronima_head_04_FEG200130_103/FEG200130_103_0223.dcm
# Error: Instance number (0020,0013) not found: //media/jake/1tb_ssd/mctv_analysis/head_scans/Paraphronima_head_04_FEG200130_103/FEG200130_103_0224.dcm
# Error: Instance number (0020,0013) not found: //media/jake/1tb_ssd/mctv_analysis/head_scans/Paraphronima_head_04_FEG200130_103/FEG200130_103_0225.dcm
# Error: Instance number (0020,0013) not found: //media/jake/1tb_ssd/mctv_analysis/head_scans/Paraphronima_head_04_FEG200130_103/FEG200130_103_0226.dcm
# Error: Instance number (0020,0013) not found: //media/jake/1tb_ssd/mctv_analysis/head_scans/Paraphronima_head_04_FEG200130_103/FEG200130_103_0227.dcm
# Error: Instance number (0020,0013) not found: //media/jake/1tb_ssd/mctv_analysis/head_scans/Paraphronima_head_04_FEG200130_103/FEG200130_103_0228.dcm
# Error: Instance number (0020,0013) not found: //media/jake/1tb_ssd/mctv_analysis/head_scans/Paraphronima_head_04_FEG200130_103/FEG200130_103_0229.dcm
# Error: Instance number (0020,0013) not found: //media/jake/1tb_ssd/mctv_analysis/head_scans/Paraphronima_head_04_FEG200130_103/FEG200130_103_0230.dcm
# Error: Instance number (0020,0013) not found: //media/jake/1tb_ssd/mctv_analysis/head_scans/Paraphronima_head_04_FEG200130_103/FEG200130_103_0231.dcm
# Error: Instance number (0020,0013) not found: //media/jake/1tb_ssd/mctv_analysis/head_scans/Paraphronima_head_04_FEG200130_103/FEG200130_103_0232.dcm
# Error: Instance number (0020,0013) not found: //media/jake/1tb_ssd/mctv_analysis/head_scans/Paraphronima_head_04_FEG200130_103/FEG200130_103_0233.dcm
# Error: Instance number (0020,0013) not found: //media/jake/1tb_ssd/mctv_analysis/head_scans/Paraphronima_head_04_FEG200130_103/FEG200130_103_0234.dcm
# Error: Instance number (0020,0013) not found: //media/jake/1tb_ssd/mctv_analysis/head_scans/Paraphronima_head_04_FEG200130_103/FEG200130_103_0235.dcm
# Error: Instance number (0020,0013) not found: //media/jake/1tb_ssd/mctv_analysis/head_scans/Paraphronima_head_04_FEG200130_103/FEG200130_103_0236.dcm
# Error: Instance number (0020,0013) not found: //media/jake/1tb_ssd/mctv_analysis/head_scans/Paraphronima_head_04_FEG200130_103/FEG200130_103_0237.dcm
# Error: Instance number (0020,0013) not found: //media/jake/1tb_ssd/mctv_analysis/head_scans/Paraphronima_head_04_FEG200130_103/FEG200130_103_0238.dcm
# Error: Instance number (0020,0013) not found: //media/jake/1tb_ssd/mctv_analysis/head_scans/Paraphronima_head_04_FEG200130_103/FEG200130_103_0239.dcm
# Error: Instance number (0020,0013) not found: //media/jake/1tb_ssd/mctv_analysis/head_scans/Paraphronima_head_04_FEG200130_103/FEG200130_103_0240.dcm
# Error: Instance number (0020,0013) not found: //media/jake/1tb_ssd/mctv_analysis/head_scans/Paraphronima_head_04_FEG200130_103/FEG200130_103_0241.dcm
# Error: Instance number (0020,0013) not found: //media/jake/1tb_ssd/mctv_analysis/head_scans/Paraphronima_head_04_FEG200130_103/FEG200130_103_0242.dcm
# Error: Instance number (0020,0013) not found: //media/jake/1tb_ssd/mctv_analysis/head_scans/Paraphronima_head_04_FEG200130_103/FEG200130_103_0243.dcm
# Error: Instance number (0020,0013) not found: //media/jake/1tb_ssd/mctv_analysis/head_scans/Paraphronima_head_04_FEG200130_103/FEG200130_103_0244.dcm
# Error: Instance number (0020,0013) not found: //media/jake/1tb_ssd/mctv_analysis/head_scans/Paraphronima_head_04_FEG200130_103/FEG200130_103_0245.dcm
# Error: Instance number (0020,0013) not found: //media/jake/1tb_ssd/mctv_analysis/head_scans/Paraphronima_head_04_FEG200130_103/FEG200130_103_0246.dcm
# Error: Instance number (0020,0013) not found: //media/jake/1tb_ssd/mctv_analysis/head_scans/Paraphronima_head_04_FEG200130_103/FEG200130_103_0247.dcm
# Error: Instance number (0020,0013) not found: //media/jake/1tb_ssd/mctv_analysis/head_scans/Paraphronima_head_04_FEG200130_103/FEG200130_103_0248.dcm
# Error: Instance number (0020,0013) not found: //media/jake/1tb_ssd/mctv_analysis/head_scans/Paraphronima_head_04_FEG200130_103/FEG200130_103_0249.dcm
# Error: Instance number (0020,0013) not found: //media/jake/1tb_ssd/mctv_analysis/head_scans/Paraphronima_head_04_FEG200130_103/FEG200130_103_0250.dcm
# Error: Instance number (0020,0013) not found: //media/jake/1tb_ssd/mctv_analysis/head_scans/Paraphronima_head_04_FEG200130_103/FEG200130_103_0251.dcm
# Error: Instance number (0020,0013) not found: //media/jake/1tb_ssd/mctv_analysis/head_scans/Paraphronima_head_04_FEG200130_103/FEG200130_103_0252.dcm
# Error: Instance number (0020,0013) not found: //media/jake/1tb_ssd/mctv_analysis/head_scans/Paraphronima_head_04_FEG200130_103/FEG200130_103_0253.dcm
# Error: Instance number (0020,0013) not found: //media/jake/1tb_ssd/mctv_analysis/head_scans/Paraphronima_head_04_FEG200130_103/FEG200130_103_0254.dcm
# Error: Instance number (0020,0013) not found: //media/jake/1tb_ssd/mctv_analysis/head_scans/Paraphronima_head_04_FEG200130_103/FEG200130_103_0255.dcm
# Error: Instance number (0020,0013) not found: //media/jake/1tb_ssd/mctv_analysis/head_scans/Paraphronima_head_04_FEG200130_103/FEG200130_103_0256.dcm
# Error: Instance number (0020,0013) not found: //media/jake/1tb_ssd/mctv_analysis/head_scans/Paraphronima_head_04_FEG200130_103/FEG200130_103_0257.dcm
# Error: Instance number (0020,0013) not found: //media/jake/1tb_ssd/mctv_analysis/head_scans/Paraphronima_head_04_FEG200130_103/FEG200130_103_0258.dcm
# Error: Instance number (0020,0013) not found: //media/jake/1tb_ssd/mctv_analysis/head_scans/Paraphronima_head_04_FEG200130_103/FEG200130_103_0259.dcm
# Error: Instance number (0020,0013) not found: //media/jake/1tb_ssd/mctv_analysis/head_scans/Paraphronima_head_04_FEG200130_103/FEG200130_103_0260.dcm
# Error: Instance number (0020,0013) not found: //media/jake/1tb_ssd/mctv_analysis/head_scans/Paraphronima_head_04_FEG200130_103/FEG200130_103_0261.dcm
# Error: Instance number (0020,0013) not found: //media/jake/1tb_ssd/mctv_analysis/head_scans/Paraphronima_head_04_FEG200130_103/FEG200130_103_0262.dcm
# Error: Instance number (0020,0013) not found: //media/jake/1tb_ssd/mctv_analysis/head_scans/Paraphronima_head_04_FEG200130_103/FEG200130_103_0263.dcm
# Error: Instance number (0020,0013) not found: //media/jake/1tb_ssd/mctv_analysis/head_scans/Paraphronima_head_04_FEG200130_103/FEG200130_103_0264.dcm
# Error: Instance number (0020,0013) not found: //media/jake/1tb_ssd/mctv_analysis/head_scans/Paraphronima_head_04_FEG200130_103/FEG200130_103_0265.dcm
# Error: Instance number (0020,0013) not found: //media/jake/1tb_ssd/mctv_analysis/head_scans/Paraphronima_head_04_FEG200130_103/FEG200130_103_0266.dcm
# Error: Instance number (0020,0013) not found: //media/jake/1tb_ssd/mctv_analysis/head_scans/Paraphronima_head_04_FEG200130_103/FEG200130_103_0267.dcm
# Error: Instance number (0020,0013) not found: //media/jake/1tb_ssd/mctv_analysis/head_scans/Paraphronima_head_04_FEG200130_103/FEG200130_103_0268.dcm
# Error: Instance number (0020,0013) not found: //media/jake/1tb_ssd/mctv_analysis/head_scans/Paraphronima_head_04_FEG200130_103/FEG200130_103_0269.dcm
# Error: Instance number (0020,0013) not found: //media/jake/1tb_ssd/mctv_analysis/head_scans/Paraphronima_head_04_FEG200130_103/FEG200130_103_0270.dcm
# Error: Instance number (0020,0013) not found: //media/jake/1tb_ssd/mctv_analysis/head_scans/Paraphronima_head_04_FEG200130_103/FEG200130_103_0271.dcm
# Error: Instance number (0020,0013) not found: //media/jake/1tb_ssd/mctv_analysis/head_scans/Paraphronima_head_04_FEG200130_103/FEG200130_103_0272.dcm
# Error: Instance number (0020,0013) not found: //media/jake/1tb_ssd/mctv_analysis/head_scans/Paraphronima_head_04_FEG200130_103/FEG200130_103_0273.dcm
# Error: Instance number (0020,0013) not found: //media/jake/1tb_ssd/mctv_analysis/head_scans/Paraphronima_head_04_FEG200130_103/FEG200130_103_0274.dcm
# Error: Instance number (0020,0013) not found: //media/jake/1tb_ssd/mctv_analysis/head_scans/Paraphronima_head_04_FEG200130_103/FEG200130_103_0275.dcm
# Error: Instance number (0020,0013) not found: //media/jake/1tb_ssd/mctv_analysis/head_scans/Paraphronima_head_04_FEG200130_103/FEG200130_103_0276.dcm
# Error: Instance number (0020,0013) not found: //media/jake/1tb_ssd/mctv_analysis/head_scans/Paraphronima_head_04_FEG200130_103/FEG200130_103_0277.dcm
# Error: Instance number (0020,0013) not found: //media/jake/1tb_ssd/mctv_analysis/head_scans/Paraphronima_head_04_FEG200130_103/FEG200130_103_0278.dcm
# Error: Instance number (0020,0013) not found: //media/jake/1tb_ssd/mctv_analysis/head_scans/Paraphronima_head_04_FEG200130_103/FEG200130_103_0279.dcm
# Error: Instance number (0020,0013) not found: //media/jake/1tb_ssd/mctv_analysis/head_scans/Paraphronima_head_04_FEG200130_103/FEG200130_103_0280.dcm
# Error: Instance number (0020,0013) not found: //media/jake/1tb_ssd/mctv_analysis/head_scans/Paraphronima_head_04_FEG200130_103/FEG200130_103_0281.dcm
# Error: Instance number (0020,0013) not found: //media/jake/1tb_ssd/mctv_analysis/head_scans/Paraphronima_head_04_FEG200130_103/FEG200130_103_0282.dcm
# Error: Instance number (0020,0013) not found: //media/jake/1tb_ssd/mctv_analysis/head_scans/Paraphronima_head_04_FEG200130_103/FEG200130_103_0283.dcm
# Error: Instance number (0020,0013) not found: //media/jake/1tb_ssd/mctv_analysis/head_scans/Paraphronima_head_04_FEG200130_103/FEG200130_103_0284.dcm
# Error: Instance number (0020,0013) not found: //media/jake/1tb_ssd/mctv_analysis/head_scans/Paraphronima_head_04_FEG200130_103/FEG200130_103_0285.dcm
# Error: Instance number (0020,0013) not found: //media/jake/1tb_ssd/mctv_analysis/head_scans/Paraphronima_head_04_FEG200130_103/FEG200130_103_0286.dcm
# Error: Instance number (0020,0013) not found: //media/jake/1tb_ssd/mctv_analysis/head_scans/Paraphronima_head_04_FEG200130_103/FEG200130_103_0287.dcm
# Error: Instance number (0020,0013) not found: //media/jake/1tb_ssd/mctv_analysis/head_scans/Paraphronima_head_04_FEG200130_103/FEG200130_103_0288.dcm
# Error: Instance number (0020,0013) not found: //media/jake/1tb_ssd/mctv_analysis/head_scans/Paraphronima_head_04_FEG200130_103/FEG200130_103_0289.dcm
# Error: Instance number (0020,0013) not found: //media/jake/1tb_ssd/mctv_analysis/head_scans/Paraphronima_head_04_FEG200130_103/FEG200130_103_0290.dcm
# Error: Instance number (0020,0013) not found: //media/jake/1tb_ssd/mctv_analysis/head_scans/Paraphronima_head_04_FEG200130_103/FEG200130_103_0291.dcm
# Error: Instance number (0020,0013) not found: //media/jake/1tb_ssd/mctv_analysis/head_scans/Paraphronima_head_04_FEG200130_103/FEG200130_103_0292.dcm
# Error: Instance number (0020,0013) not found: //media/jake/1tb_ssd/mctv_analysis/head_scans/Paraphronima_head_04_FEG200130_103/FEG200130_103_0293.dcm
# Error: Instance number (0020,0013) not found: //media/jake/1tb_ssd/mctv_analysis/head_scans/Paraphronima_head_04_FEG200130_103/FEG200130_103_0294.dcm
# Error: Instance number (0020,0013) not found: //media/jake/1tb_ssd/mctv_analysis/head_scans/Paraphronima_head_04_FEG200130_103/FEG200130_103_0295.dcm
# Error: Instance number (0020,0013) not found: //media/jake/1tb_ssd/mctv_analysis/head_scans/Paraphronima_head_04_FEG200130_103/FEG200130_103_0296.dcm
# Error: Instance number (0020,0013) not found: //media/jake/1tb_ssd/mctv_analysis/head_scans/Paraphronima_head_04_FEG200130_103/FEG200130_103_0297.dcm
# Error: Instance number (0020,0013) not found: //media/jake/1tb_ssd/mctv_analysis/head_scans/Paraphronima_head_04_FEG200130_103/FEG200130_103_0298.dcm
# Error: Instance number (0020,0013) not found: //media/jake/1tb_ssd/mctv_analysis/head_scans/Paraphronima_head_04_FEG200130_103/FEG200130_103_0299.dcm
# Error: Instance number (0020,0013) not found: //media/jake/1tb_ssd/mctv_analysis/head_scans/Paraphronima_head_04_FEG200130_103/FEG200130_103_0300.dcm
# Error: Instance number (0020,0013) not found: //media/jake/1tb_ssd/mctv_analysis/head_scans/Paraphronima_head_04_FEG200130_103/FEG200130_103_0301.dcm
# Error: Instance number (0020,0013) not found: //media/jake/1tb_ssd/mctv_analysis/head_scans/Paraphronima_head_04_FEG200130_103/FEG200130_103_0302.dcm
# Error: Instance number (0020,0013) not found: //media/jake/1tb_ssd/mctv_analysis/head_scans/Paraphronima_head_04_FEG200130_103/FEG200130_103_0303.dcm
# Error: Instance number (0020,0013) not found: //media/jake/1tb_ssd/mctv_analysis/head_scans/Paraphronima_head_04_FEG200130_103/FEG200130_103_0304.dcm
# Error: Instance number (0020,0013) not found: //media/jake/1tb_ssd/mctv_analysis/head_scans/Paraphronima_head_04_FEG200130_103/FEG200130_103_0305.dcm
# Error: Instance number (0020,0013) not found: //media/jake/1tb_ssd/mctv_analysis/head_scans/Paraphronima_head_04_FEG200130_103/FEG200130_103_0306.dcm
# Error: Instance number (0020,0013) not found: //media/jake/1tb_ssd/mctv_analysis/head_scans/Paraphronima_head_04_FEG200130_103/FEG200130_103_0307.dcm
# Error: Instance number (0020,0013) not found: //media/jake/1tb_ssd/mctv_analysis/head_scans/Paraphronima_head_04_FEG200130_103/FEG200130_103_0308.dcm
# Error: Instance number (0020,0013) not found: //media/jake/1tb_ssd/mctv_analysis/head_scans/Paraphronima_head_04_FEG200130_103/FEG200130_103_0309.dcm
# Error: Instance number (0020,0013) not found: //media/jake/1tb_ssd/mctv_analysis/head_scans/Paraphronima_head_04_FEG200130_103/FEG200130_103_0310.dcm
# Error: Instance number (0020,0013) not found: //media/jake/1tb_ssd/mctv_analysis/head_scans/Paraphronima_head_04_FEG200130_103/FEG200130_103_0311.dcm
# Error: Instance number (0020,0013) not found: //media/jake/1tb_ssd/mctv_analysis/head_scans/Paraphronima_head_04_FEG200130_103/FEG200130_103_0312.dcm
# Error: Instance number (0020,0013) not found: //media/jake/1tb_ssd/mctv_analysis/head_scans/Paraphronima_head_04_FEG200130_103/FEG200130_103_0313.dcm
# Error: Instance number (0020,0013) not found: //media/jake/1tb_ssd/mctv_analysis/head_scans/Paraphronima_head_04_FEG200130_103/FEG200130_103_0314.dcm
# Error: Instance number (0020,0013) not found: //media/jake/1tb_ssd/mctv_analysis/head_scans/Paraphronima_head_04_FEG200130_103/FEG200130_103_0315.dcm
# Error: Instance number (0020,0013) not found: //media/jake/1tb_ssd/mctv_analysis/head_scans/Paraphronima_head_04_FEG200130_103/FEG200130_103_0316.dcm
# Error: Instance number (0020,0013) not found: //media/jake/1tb_ssd/mctv_analysis/head_scans/Paraphronima_head_04_FEG200130_103/FEG200130_103_0317.dcm
# ...
# Error: Instance number (0020,0013) not found: //media/jake/1tb_ssd/mctv_analysis/head_scans/Pronoe_sp6_1450786A/Pronoe_sp6_1450786A187.dcm
# Error: Instance number (0020,0013) not found: //media/jake/1tb_ssd/mctv_analysis/head_scans/Pronoe_sp6_1450786A/Pronoe_sp6_1450786A188.dcm
# Error: Instance number (0020,0013) not found: //media/jake/1tb_ssd/mctv_analysis/head_scans/Pronoe_sp6_1450786A/Pronoe_sp6_1450786A189.dcm
# Error: Instance number (0020,0013) not found: //media/jake/1tb_ssd/mctv_analysis/head_scans/Pronoe_sp6_1450786A/Pronoe_sp6_1450786A190.dcm
# Error: Instance number (0020,0013) not found: //media/jake/1tb_ssd/mctv_analysis/head_scans/Pronoe_sp6_1450786A/Pronoe_sp6_1450786A191.dcm
# Error: Instance number (0020,0013) not found: //media/jake/1tb_ssd/mctv_analysis/head_scans/Pronoe_sp6_1450786A/Pronoe_sp6_1450786A192.dcm
# Error: Instance number (0020,0013) not found: //media/jake/1tb_ssd/mctv_analysis/head_scans/Pronoe_sp6_1450786A/Pronoe_sp6_1450786A193.dcm
# Error: Instance number (0020,0013) not found: //media/jake/1tb_ssd/mctv_analysis/head_scans/Pronoe_sp6_1450786A/Pronoe_sp6_1450786A194.dcm
# Error: Instance number (0020,0013) not found: //media/jake/1tb_ssd/mctv_analysis/head_scans/Pronoe_sp6_1450786A/Pronoe_sp6_1450786A195.dcm
# Error: Instance number (0020,0013) not found: //media/jake/1tb_ssd/mctv_analysis/head_scans/Pronoe_sp6_1450786A/Pronoe_sp6_1450786A196.dcm
# Error: Instance number (0020,0013) not found: //media/jake/1tb_ssd/mctv_analysis/head_scans/Pronoe_sp6_1450786A/Pronoe_sp6_1450786A197.dcm
# Error: Instance number (0020,0013) not found: //media/jake/1tb_ssd/mctv_analysis/head_scans/Pronoe_sp6_1450786A/Pronoe_sp6_1450786A198.dcm
# Error: Instance number (0020,0013) not found: //media/jake/1tb_ssd/mctv_analysis/head_scans/Pronoe_sp6_1450786A/Pronoe_sp6_1450786A199.dcm
# Error: Instance number (0020,0013) not found: //media/jake/1tb_ssd/mctv_analysis/head_scans/Pronoe_sp6_1450786A/Pronoe_sp6_1450786A200.dcm
# Error: Instance number (0020,0013) not found: //media/jake/1tb_ssd/mctv_analysis/head_scans/Pronoe_sp6_1450786A/Pronoe_sp6_1450786A201.dcm
# Error: Instance number (0020,0013) not found: //media/jake/1tb_ssd/mctv_analysis/head_scans/Pronoe_sp6_1450786A/Pronoe_sp6_1450786A202.dcm
# Error: Instance number (0020,0013) not found: //media/jake/1tb_ssd/mctv_analysis/head_scans/Pronoe_sp6_1450786A/Pronoe_sp6_1450786A203.dcm
# Error: Instance number (0020,0013) not found: //media/jake/1tb_ssd/mctv_analysis/head_scans/Pronoe_sp6_1450786A/Pronoe_sp6_1450786A204.dcm
# Error: Instance number (0020,0013) not found: //media/jake/1tb_ssd/mctv_analysis/head_scans/Pronoe_sp6_1450786A/Pronoe_sp6_1450786A205.dcm
# Error: Instance number (0020,0013) not found: //media/jake/1tb_ssd/mctv_analysis/head_scans/Pronoe_sp6_1450786A/Pronoe_sp6_1450786A206.dcm
# Error: Instance number (0020,0013) not found: //media/jake/1tb_ssd/mctv_analysis/head_scans/Pronoe_sp6_1450786A/Pronoe_sp6_1450786A207.dcm
# Error: Instance number (0020,0013) not found: //media/jake/1tb_ssd/mctv_analysis/head_scans/Pronoe_sp6_1450786A/Pronoe_sp6_1450786A208.dcm
# Error: Instance number (0020,0013) not found: //media/jake/1tb_ssd/mctv_analysis/head_scans/Pronoe_sp6_1450786A/Pronoe_sp6_1450786A209.dcm
# Error: Instance number (0020,0013) not found: //media/jake/1tb_ssd/mctv_analysis/head_scans/Pronoe_sp6_1450786A/Pronoe_sp6_1450786A210.dcm
# Error: Instance number (0020,0013) not found: //media/jake/1tb_ssd/mctv_analysis/head_scans/Pronoe_sp6_1450786A/Pronoe_sp6_1450786A211.dcm
# Error: Instance number (0020,0013) not found: //media/jake/1tb_ssd/mctv_analysis/head_scans/Pronoe_sp6_1450786A/Pronoe_sp6_1450786A212.dcm
# Error: Instance number (0020,0013) not found: //media/jake/1tb_ssd/mctv_analysis/head_scans/Pronoe_sp6_1450786A/Pronoe_sp6_1450786A213.dcm
# Error: Instance number (0020,0013) not found: //media/jake/1tb_ssd/mctv_analysis/head_scans/Pronoe_sp6_1450786A/Pronoe_sp6_1450786A214.dcm
# Error: Instance number (0020,0013) not found: //media/jake/1tb_ssd/mctv_analysis/head_scans/Pronoe_sp6_1450786A/Pronoe_sp6_1450786A215.dcm
# Error: Instance number (0020,0013) not found: //media/jake/1tb_ssd/mctv_analysis/head_scans/Pronoe_sp6_1450786A/Pronoe_sp6_1450786A216.dcm
# Error: Instance number (0020,0013) not found: //media/jake/1tb_ssd/mctv_analysis/head_scans/Pronoe_sp6_1450786A/Pronoe_sp6_1450786A217.dcm
# Error: Instance number (0020,0013) not found: //media/jake/1tb_ssd/mctv_analysis/head_scans/Pronoe_sp6_1450786A/Pronoe_sp6_1450786A218.dcm
# Error: Instance number (0020,0013) not found: //media/jake/1tb_ssd/mctv_analysis/head_scans/Pronoe_sp6_1450786A/Pronoe_sp6_1450786A219.dcm
# Error: Instance number (0020,0013) not found: //media/jake/1tb_ssd/mctv_analysis/head_scans/Pronoe_sp6_1450786A/Pronoe_sp6_1450786A220.dcm
# Error: Instance number (0020,0013) not found: //media/jake/1tb_ssd/mctv_analysis/head_scans/Pronoe_sp6_1450786A/Pronoe_sp6_1450786A221.dcm
# Error: Instance number (0020,0013) not found: //media/jake/1tb_ssd/mctv_analysis/head_scans/Pronoe_sp6_1450786A/Pronoe_sp6_1450786A222.dcm
# Error: Instance number (0020,0013) not found: //media/jake/1tb_ssd/mctv_analysis/head_scans/Pronoe_sp6_1450786A/Pronoe_sp6_1450786A223.dcm
# Error: Instance number (0020,0013) not found: //media/jake/1tb_ssd/mctv_analysis/head_scans/Pronoe_sp6_1450786A/Pronoe_sp6_1450786A224.dcm
# Error: Instance number (0020,0013) not found: //media/jake/1tb_ssd/mctv_analysis/head_scans/Pronoe_sp6_1450786A/Pronoe_sp6_1450786A225.dcm
# Error: Instance number (0020,0013) not found: //media/jake/1tb_ssd/mctv_analysis/head_scans/Pronoe_sp6_1450786A/Pronoe_sp6_1450786A226.dcm
# Error: Instance number (0020,0013) not found: //media/jake/1tb_ssd/mctv_analysis/head_scans/Pronoe_sp6_1450786A/Pronoe_sp6_1450786A227.dcm
# Error: Instance number (0020,0013) not found: //media/jake/1tb_ssd/mctv_analysis/head_scans/Pronoe_sp6_1450786A/Pronoe_sp6_1450786A228.dcm
# Error: Instance number (0020,0013) not found: //media/jake/1tb_ssd/mctv_analysis/head_scans/Pronoe_sp6_1450786A/Pronoe_sp6_1450786A229.dcm
# Error: Instance number (0020,0013) not found: //media/jake/1tb_ssd/mctv_analysis/head_scans/Pronoe_sp6_1450786A/Pronoe_sp6_1450786A230.dcm
# Error: Instance number (0020,0013) not found: //media/jake/1tb_ssd/mctv_analysis/head_scans/Pronoe_sp6_1450786A/Pronoe_sp6_1450786A231.dcm
# Error: Instance number (0020,0013) not found: //media/jake/1tb_ssd/mctv_analysis/head_scans/Pronoe_sp6_1450786A/Pronoe_sp6_1450786A232.dcm
# Error: Instance number (0020,0013) not found: //media/jake/1tb_ssd/mctv_analysis/head_scans/Pronoe_sp6_1450786A/Pronoe_sp6_1450786A233.dcm
# Error: Instance number (0020,0013) not found: //media/jake/1tb_ssd/mctv_analysis/head_scans/Pronoe_sp6_1450786A/Pronoe_sp6_1450786A234.dcm
# Error: Instance number (0020,0013) not found: //media/jake/1tb_ssd/mctv_analysis/head_scans/Pronoe_sp6_1450786A/Pronoe_sp6_1450786A235.dcm
# Error: Instance number (0020,0013) not found: //media/jake/1tb_ssd/mctv_analysis/head_scans/Pronoe_sp6_1450786A/Pronoe_sp6_1450786A236.dcm
# Error: Instance number (0020,0013) not found: //media/jake/1tb_ssd/mctv_analysis/head_scans/Pronoe_sp6_1450786A/Pronoe_sp6_1450786A237.dcm
# Error: Instance number (0020,0013) not found: //media/jake/1tb_ssd/mctv_analysis/head_scans/Pronoe_sp6_1450786A/Pronoe_sp6_1450786A238.dcm
# Error: Instance number (0020,0013) not found: //media/jake/1tb_ssd/mctv_analysis/head_scans/Pronoe_sp6_1450786A/Pronoe_sp6_1450786A239.dcm
# Error: Instance number (0020,0013) not found: //media/jake/1tb_ssd/mctv_analysis/head_scans/Pronoe_sp6_1450786A/Pronoe_sp6_1450786A240.dcm
# Error: Instance number (0020,0013) not found: //media/jake/1tb_ssd/mctv_analysis/head_scans/Pronoe_sp6_1450786A/Pronoe_sp6_1450786A241.dcm
# Error: Instance number (0020,0013) not found: //media/jake/1tb_ssd/mctv_analysis/head_scans/Pronoe_sp6_1450786A/Pronoe_sp6_1450786A242.dcm
# Error: Instance number (0020,0013) not found: //media/jake/1tb_ssd/mctv_analysis/head_scans/Pronoe_sp6_1450786A/Pronoe_sp6_1450786A243.dcm
# Error: Instance number (0020,0013) not found: //media/jake/1tb_ssd/mctv_analysis/head_scans/Pronoe_sp6_1450786A/Pronoe_sp6_1450786A244.dcm
# Error: Instance number (0020,0013) not found: //media/jake/1tb_ssd/mctv_analysis/head_scans/Pronoe_sp6_1450786A/Pronoe_sp6_1450786A245.dcm
# Error: Instance number (0020,0013) not found: //media/jake/1tb_ssd/mctv_analysis/head_scans/Pronoe_sp6_1450786A/Pronoe_sp6_1450786A246.dcm
# Error: Instance number (0020,0013) not found: //media/jake/1tb_ssd/mctv_analysis/head_scans/Pronoe_sp6_1450786A/Pronoe_sp6_1450786A247.dcm
# Error: Instance number (0020,0013) not found: //media/jake/1tb_ssd/mctv_analysis/head_scans/Pronoe_sp6_1450786A/Pronoe_sp6_1450786A248.dcm
# Error: Instance number (0020,0013) not found: //media/jake/1tb_ssd/mctv_analysis/head_scans/Pronoe_sp6_1450786A/Pronoe_sp6_1450786A249.dcm
# Error: Instance number (0020,0013) not found: //media/jake/1tb_ssd/mctv_analysis/head_scans/Pronoe_sp6_1450786A/Pronoe_sp6_1450786A250.dcm
# Error: Instance number (0020,0013) not found: //media/jake/1tb_ssd/mctv_analysis/head_scans/Pronoe_sp6_1450786A/Pronoe_sp6_1450786A251.dcm
# Error: Instance number (0020,0013) not found: //media/jake/1tb_ssd/mctv_analysis/head_scans/Pronoe_sp6_1450786A/Pronoe_sp6_1450786A252.dcm
# Error: Instance number (0020,0013) not found: //media/jake/1tb_ssd/mctv_analysis/head_scans/Pronoe_sp6_1450786A/Pronoe_sp6_1450786A253.dcm
# Error: Instance number (0020,0013) not found: //media/jake/1tb_ssd/mctv_analysis/head_scans/Pronoe_sp6_1450786A/Pronoe_sp6_1450786A254.dcm
# Error: Instance number (0020,0013) not found: //media/jake/1tb_ssd/mctv_analysis/head_scans/Pronoe_sp6_1450786A/Pronoe_sp6_1450786A255.dcm
# Error: Instance number (0020,0013) not found: //media/jake/1tb_ssd/mctv_analysis/head_scans/Pronoe_sp6_1450786A/Pronoe_sp6_1450786A256.dcm
# Error: Instance number (0020,0013) not found: //media/jake/1tb_ssd/mctv_analysis/head_scans/Pronoe_sp6_1450786A/Pronoe_sp6_1450786A257.dcm
# Error: Instance number (0020,0013) not found: //media/jake/1tb_ssd/mctv_analysis/head_scans/Pronoe_sp6_1450786A/Pronoe_sp6_1450786A258.dcm
# Error: Instance number (0020,0013) not found: //media/jake/1tb_ssd/mctv_analysis/head_scans/Pronoe_sp6_1450786A/Pronoe_sp6_1450786A259.dcm
# Error: Instance number (0020,0013) not found: //media/jake/1tb_ssd/mctv_analysis/head_scans/Pronoe_sp6_1450786A/Pronoe_sp6_1450786A260.dcm
# Error: Instance number (0020,0013) not found: //media/jake/1tb_ssd/mctv_analysis/head_scans/Pronoe_sp6_1450786A/Pronoe_sp6_1450786A261.dcm
# Error: Instance number (0020,0013) not found: //media/jake/1tb_ssd/mctv_analysis/head_scans/Pronoe_sp6_1450786A/Pronoe_sp6_1450786A262.dcm
# Error: Instance number (0020,0013) not found: //media/jake/1tb_ssd/mctv_analysis/head_scans/Pronoe_sp6_1450786A/Pronoe_sp6_1450786A263.dcm
# Error: Instance number (0020,0013) not found: //media/jake/1tb_ssd/mctv_analysis/head_scans/Pronoe_sp6_1450786A/Pronoe_sp6_1450786A264.dcm
# Error: Instance number (0020,0013) not found: //media/jake/1tb_ssd/mctv_analysis/head_scans/Pronoe_sp6_1450786A/Pronoe_sp6_1450786A265.dcm
# Error: Instance number (0020,0013) not found: //media/jake/1tb_ssd/mctv_analysis/head_scans/Pronoe_sp6_1450786A/Pronoe_sp6_1450786A266.dcm
# Error: Instance number (0020,0013) not found: //media/jake/1tb_ssd/mctv_analysis/head_scans/Pronoe_sp6_1450786A/Pronoe_sp6_1450786A267.dcm
# Error: Instance number (0020,0013) not found: //media/jake/1tb_ssd/mctv_analysis/head_scans/Pronoe_sp6_1450786A/Pronoe_sp6_1450786A268.dcm
# Error: Instance number (0020,0013) not found: //media/jake/1tb_ssd/mctv_analysis/head_scans/Pronoe_sp6_1450786A/Pronoe_sp6_1450786A269.dcm
# Error: Instance number (0020,0013) not found: //media/jake/1tb_ssd/mctv_analysis/head_scans/Pronoe_sp6_1450786A/Pronoe_sp6_1450786A270.dcm
# Error: Instance number (0020,0013) not found: //media/jake/1tb_ssd/mctv_analysis/head_scans/Pronoe_sp6_1450786A/Pronoe_sp6_1450786A271.dcm
# Error: Instance number (0020,0013) not found: //media/jake/1tb_ssd/mctv_analysis/head_scans/Pronoe_sp6_1450786A/Pronoe_sp6_1450786A272.dcm
# Error: Instance number (0020,0013) not found: //media/jake/1tb_ssd/mctv_analysis/head_scans/Pronoe_sp6_1450786A/Pronoe_sp6_1450786A273.dcm
# Error: Instance number (0020,0013) not found: //media/jake/1tb_ssd/mctv_analysis/head_scans/Pronoe_sp6_1450786A/Pronoe_sp6_1450786A274.dcm
# Error: Instance number (0020,0013) not found: //media/jake/1tb_ssd/mctv_analysis/head_scans/Pronoe_sp6_1450786A/Pronoe_sp6_1450786A275.dcm
# Error: Instance number (0020,0013) not found: //media/jake/1tb_ssd/mctv_analysis/head_scans/Pronoe_sp6_1450786A/Pronoe_sp6_1450786A276.dcm
# Error: Instance number (0020,0013) not found: //media/jake/1tb_ssd/mctv_analysis/head_scans/Pronoe_sp6_1450786A/Pronoe_sp6_1450786A277.dcm
# Error: Instance number (0020,0013) not found: //media/jake/1tb_ssd/mctv_analysis/head_scans/Pronoe_sp6_1450786A/Pronoe_sp6_1450786A278.dcm
# Error: Instance number (0020,0013) not found: //media/jake/1tb_ssd/mctv_analysis/head_scans/Pronoe_sp6_1450786A/Pronoe_sp6_1450786A279.dcm
# Error: Instance number (0020,0013) not found: //media/jake/1tb_ssd/mctv_analysis/head_scans/Pronoe_sp6_1450786A/Pronoe_sp6_1450786A280.dcm
# Error: Instance number (0020,0013) not found: //media/jake/1tb_ssd/mctv_analysis/head_scans/Pronoe_sp6_1450786A/Pronoe_sp6_1450786A281.dcm
# Error: Instance number (0020,0013) not found: //media/jake/1tb_ssd/mctv_analysis/head_scans/Pronoe_sp6_1450786A/Pronoe_sp6_1450786A282.dcm
# Error: Instance number (0020,0013) not found: //media/jake/1tb_ssd/mctv_analysis/head_scans/Pronoe_sp6_1450786A/Pronoe_sp6_1450786A283.dcm
# Error: Instance number (0020,0013) not found: //media/jake/1tb_ssd/mctv_analysis/head_scans/Pronoe_sp6_1450786A/Pronoe_sp6_1450786A284.dcm
# Error: Instance number (0020,0013) not found: //media/jake/1tb_ssd/mctv_analysis/head_scans/Pronoe_sp6_1450786A/Pronoe_sp6_1450786A285.dcm
# Error: Instance number (0020,0013) not found: //media/jake/1tb_ssd/mctv_analysis/head_scans/Pronoe_sp6_1450786A/Pronoe_sp6_1450786A286.dcm
# Error: Instance number (0020,0013) not found: //media/jake/1tb_ssd/mctv_analysis/head_scans/Pronoe_sp6_1450786A/Pronoe_sp6_1450786A287.dcm
# Error: Instance number (0020,0013) not found: //media/jake/1tb_ssd/mctv_analysis/head_scans/Pronoe_sp6_1450786A/Pronoe_sp6_1450786A288.dcm
# Warning: Empty protocol name(s) (0018,1030)
# 734 images have identical time, series, acquisition and instance values. DUPLICATES REMOVED.
# Convert 1 DICOM as //media/jake/data/jake/mctnet_data/raw_images/Pronoe_sp6_1450786A (960x705x1x1)
# Warning: Check that 2D images are not mirrored.
# DICOM row order preserved: may appear upside down in tools that ignore spatial transforms
# Conversion required 0.814324 seconds.
# Found 1226 DICOM file(s)
# Error: Instance number (0020,0013) not found: //media/jake/1tb_ssd/mctv_analysis/head_scans/P_crassipes_FEG200129_099_cropped/FEG200129_099_0001.dcm
# 1 images have identical time, series, acquisition and instance values. DUPLICATES REMOVED.
# Convert 1225 DICOM as //media/jake/data/jake/mctnet_data/raw_images/P_crassipes_FEG200129_099_cropped (593x823x1225x1)
# DICOM row order preserved: may appear upside down in tools that ignore spatial transforms
# Conversion required 2.501336 seconds.
# Found 482 DICOM file(s)
# Error: Instance number (0020,0013) not found: //media/jake/1tb_ssd/mctv_analysis/head_scans/Phronima_1450842_body_3_slices/Pronima_1450842_body00000.dcm
# Warning: Empty protocol name(s) (0018,1030)
# 1 images have identical time, series, acquisition and instance values. DUPLICATES REMOVED.
# Convert 481 DICOM as //media/jake/data/jake/mctnet_data/raw_images/Phronima_1450842_body_3_slices (955x881x481x1)
# DICOM row order preserved: may appear upside down in tools that ignore spatial transforms
# Conversion required 1.665939 seconds.
# Found 1660 DICOM file(s)
# Error: Instance number (0020,0013) not found: //media/jake/1tb_ssd/mctv_analysis/head_scans/Phronima_sp_5_USNM1450842/Paraphronima_sp_8_1423158-slices/Phronima_sp_5_USNM145084200000.dcm

# %% [markdown]
# # Move raw labels
# Now that all our images are in our raw_images folder. Let's move the raw labels over too.

# %% [markdown]
# # DON'T USE
# # Convert dicom to nifti alternative (doesn't seem to work too well with some dicom files.
# # appears to be a problem with dicom2nifti)
#
# Let's start by making a function that can convert our dicom directories to nifti.

# %%
def convert_nifti_to_dicom(d):
    print(f'Starting conversion of {d} \n...\n')

    p = Path(d)
    filename = p.stem
    new_path = raw_image_dir + "/" + filename + '.nii'
    
    if not os.path.isfile(new_path):
        dicom2nifti.dicom_series_to_nifti(d, new_path, reorient_nifti=True)
        print(f'Converted dicom {d} to {new_path}\n')
    else:
        print(f'File {new_path} already exists, so skipped this conversion\n')

# %% [markdown]
# To make this faster, let's create some multiprocessing helper functions

# %%
import multiprocessing

# split a list into evenly sized chunks
def chunks(l, n):
    return [l[i:i+n] for i in range(0, len(l), n)]

def do_job(job_id, data, func):
    for item in data:
        print(f'Worker {job_id} doing job\n')
        func(item)

def dispatch_jobs(job_number, data, func):
    total = len(data)
    chunk_size = total / job_number
    slice = chunks(data, int(chunk_size))
    jobs = []

    for i, s in enumerate(slice):
        j = multiprocessing.Process(target=do_job, args=(i, s, func))
        jobs.append(j)
    for j in jobs:
        j.start()

# %% [markdown]
# Now let's run this function over our data!

# %%
print(f'Converting {len(dicom_dirs)} dicom scans to nifti')

starttime = time.time()

dispatch_jobs(6, dicom_dirs, convert_nifti_to_dicom)

print('That took {} seconds'.format(time.time() - starttime))
# Out:
# Converting 70 dicom scans to nifti
# Worker 0 doing job
# Starting conversion of /media/jake/1tb_ssd/mctv_analysis/head_scans/flammula_male_23_6_left
# ...
# Starting conversion of /media/jake/1tb_ssd/mctv_analysis/head_scans/Eupronoe_03_sp_6_A
# ...
# Worker 1 doing job
#
# File /media/jake/data/jake/mctnet_data/raw_images/flammula_male_23_6_left.nii already exists, so skipped this conversion
#
#
# Worker 0 doing jobWorker 2 doing job
#
# Starting conversion of /media/jake/1tb_ssd/mctv_analysis/head_scans/Eupronoe_03_sp_6_A/Leptocotis_FEG190214_004a_body_slices
# ...
# Starting conversion of /media/jake/1tb_ssd/mctv_analysis/head_scans/Hyperia_FEG190604_013A-slices-body
# ...
#
#
# File /media/jake/data/jake/mctnet_data/raw_images/Leptocotis_FEG190214_004a_body_slices.nii already exists, so skipped this conversion
# Worker 3 doing job
#
# Worker 0 doing jobStarting conversion of /media/jake/1tb_ssd/mctv_analysis/head_scans/Lanceola_01_head_FEG190802_037
# ...
# Worker 4 doing jobThat took 0.05334925651550293 seconds
#
#
# Starting conversion of /media/jake/1tb_ssd/mctv_analysis/head_scans/Schypholanceola_FEG190801_036_head
# ...
#
# File /media/jake/data/jake/mctnet_data/raw_images/Lanceola_01_head_FEG190802_037.nii already exists, so skipped this conversion
#
#
# Starting conversion of /media/jake/1tb_ssd/mctv_analysis/head_scans/Paraphronima_FEG191028_078/FEG191028_078_dcm
# ...
# Worker 5 doing job
# Worker 3 doing job
#
# Starting conversion of /media/jake/1tb_ssd/mctv_analysis/head_scans/Paraphronima_FEG181024_03_head_sp3_1423158b
# ...
# Starting conversion of /media/jake/1tb_ssd/mctv_analysis/head_scans/P_crassipes_FEG191022_077B_highpriority
# ...
#
#
# File /media/jake/data/jake/mctnet_data/raw_images/P_crassipes_FEG191022_077B_highpriority.nii already exists, so skipped this conversion
#
# Worker 6 doing jobWorker 5 doing job
#
# Starting conversion of /media/jake/1tb_ssd/mctv_analysis/head_scans/Cystisoma_FEG190801_035_brain
# ...
#
# Starting conversion of /media/jake/1tb_ssd/mctv_analysis/head_scans/Cystisoma_FEG20190212_01_head
# ...
# File /media/jake/data/jake/mctnet_data/raw_images/Cystisoma_FEG190801_035_brain.nii already exists, so skipped this conversion
#
#
# Worker 5 doing job
# Starting conversion of /media/jake/1tb_ssd/mctv_analysis/head_scans/Hyperia_head_7_1432188A
# ...
#
# Converted dicom /media/jake/1tb_ssd/mctv_analysis/head_scans/Hyperia_FEG190604_013A-slices-body to /media/jake/data/jake/mctnet_data/raw_images/Hyperia_FEG190604_013A-slices-body.nii
#
# Worker 2 doing job
# Starting conversion of /media/jake/1tb_ssd/mctv_analysis/head_scans/Vibilia_FEG191112_081_blurry
# ...
#
# File /media/jake/data/jake/mctnet_data/raw_images/Vibilia_FEG191112_081_blurry.nii already exists, so skipped this conversion
#
# Worker 2 doing job
# Starting conversion of /media/jake/1tb_ssd/mctv_analysis/head_scans/Phrosina_FEG200310_110
# ...
# Process Process-32:
# Traceback (most recent call last):
#   File "/usr/lib/python3.8/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/usr/lib/python3.8/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/tmp/ipykernel_767898/2836884920.py", line 10, in do_job
#     func(item)
#   File "/tmp/ipykernel_767898/1759632588.py", line 9, in convert_nifti_to_dicom
#     dicom2nifti.dicom_series_to_nifti(d, new_path, reorient_nifti=True)
#   File "/home/jake/projects/mctnet/venv/lib/python3.8/site-packages/dicom2nifti/convert_dicom.py", line 78, in dicom_series_to_nifti
#     return dicom_array_to_nifti(dicom_input, output_file, reorient_nifti)
#   File "/home/jake/projects/mctnet/venv/lib/python3.8/site-packages/dicom2nifti/convert_dicom.py", line 112, in dicom_array_to_nifti
#     if not are_imaging_dicoms(dicom_list):
#   File "/home/jake/projects/mctnet/venv/lib/python3.8/site-packages/dicom2nifti/convert_dicom.py", line 151, in are_imaging_dicoms
#     if common.is_philips(dicom_input):
#   File "/home/jake/projects/mctnet/venv/lib/python3.8/site-packages/dicom2nifti/common.py", line 102, in is_philips
#     header = dicom_input[0]
# IndexError: list index out of range
# Process Process-34:
# Traceback (most recent call last):
#   File "/usr/lib/python3.8/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/usr/lib/python3.8/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/tmp/ipykernel_767898/2836884920.py", line 10, in do_job
#     func(item)
#   File "/tmp/ipykernel_767898/1759632588.py", line 9, in convert_nifti_to_dicom
#     dicom2nifti.dicom_series_to_nifti(d, new_path, reorient_nifti=True)
#   File "/home/jake/projects/mctnet/venv/lib/python3.8/site-packages/dicom2nifti/convert_dicom.py", line 78, in dicom_series_to_nifti
#     return dicom_array_to_nifti(dicom_input, output_file, reorient_nifti)
#   File "/home/jake/projects/mctnet/venv/lib/python3.8/site-packages/dicom2nifti/convert_dicom.py", line 112, in dicom_array_to_nifti
#     if not are_imaging_dicoms(dicom_list):
#   File "/home/jake/projects/mctnet/venv/lib/python3.8/site-packages/dicom2nifti/convert_dicom.py", line 151, in are_imaging_dicoms
#     if common.is_philips(dicom_input):
#   File "/home/jake/projects/mctnet/venv/lib/python3.8/site-packages/dicom2nifti/common.py", line 102, in is_philips
#     header = dicom_input[0]
# IndexError: list index out of range
# Process Process-31:
# Traceback (most recent call last):
#   File "/usr/lib/python3.8/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/usr/lib/python3.8/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/tmp/ipykernel_767898/2836884920.py", line 10, in do_job
#     func(item)
#   File "/tmp/ipykernel_767898/1759632588.py", line 9, in convert_nifti_to_dicom
#     dicom2nifti.dicom_series_to_nifti(d, new_path, reorient_nifti=True)
#   File "/home/jake/projects/mctnet/venv/lib/python3.8/site-packages/dicom2nifti/convert_dicom.py", line 78, in dicom_series_to_nifti
#     return dicom_array_to_nifti(dicom_input, output_file, reorient_nifti)
#   File "/home/jake/projects/mctnet/venv/lib/python3.8/site-packages/dicom2nifti/convert_dicom.py", line 112, in dicom_array_to_nifti
#     if not are_imaging_dicoms(dicom_list):
#   File "/home/jake/projects/mctnet/venv/lib/python3.8/site-packages/dicom2nifti/convert_dicom.py", line 151, in are_imaging_dicoms
#     if common.is_philips(dicom_input):
#   File "/home/jake/projects/mctnet/venv/lib/python3.8/site-packages/dicom2nifti/common.py", line 102, in is_philips
#     header = dicom_input[0]
# IndexError: list index out of range
# Process Process-30:
# Traceback (most recent call last):
#   File "/usr/lib/python3.8/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/usr/lib/python3.8/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/tmp/ipykernel_767898/2836884920.py", line 10, in do_job
#     func(item)
#   File "/tmp/ipykernel_767898/1759632588.py", line 9, in convert_nifti_to_dicom
#     dicom2nifti.dicom_series_to_nifti(d, new_path, reorient_nifti=True)
#   File "/home/jake/projects/mctnet/venv/lib/python3.8/site-packages/dicom2nifti/convert_dicom.py", line 78, in dicom_series_to_nifti
#     return dicom_array_to_nifti(dicom_input, output_file, reorient_nifti)
#   File "/home/jake/projects/mctnet/venv/lib/python3.8/site-packages/dicom2nifti/convert_dicom.py", line 118, in dicom_array_to_nifti
#     results = convert_generic.dicom_to_nifti(dicom_list, output_file)
#   File "/home/jake/projects/mctnet/venv/lib/python3.8/site-packages/dicom2nifti/convert_generic.py", line 77, in dicom_to_nifti
#     data = common.get_volume_pixeldata(dicom_input)
#   File "/home/jake/projects/mctnet/venv/lib/python3.8/site-packages/dicom2nifti/common.py", line 210, in get_volume_pixeldata
#     vol = numpy.concatenate(slices, axis=0)
#   File "<__array_function__ internals>", line 5, in concatenate
# ValueError: all the input array dimensions for the concatenation axis must match exactly, but along dimension 1, the array at index 0 has size 613 and the array at index 1 has size 621
# Converted dicom /media/jake/1tb_ssd/mctv_analysis/head_scans/Cystisoma_FEG20190212_01_head to /media/jake/data/jake/mctnet_data/raw_images/Cystisoma_FEG20190212_01_head.nii
#
# Worker 6 doing job
# Starting conversion of /media/jake/1tb_ssd/mctv_analysis/head_scans/Scina_02_sp_2_1450794_slices
# ...
#
# File /media/jake/data/jake/mctnet_data/raw_images/Scina_02_sp_2_1450794_slices.nii already exists, so skipped this conversion
#
# Worker 6 doing job
# Starting conversion of /media/jake/1tb_ssd/mctv_analysis/head_scans/Leptocotis_01_head_FEG190214_005a
# ...
#
# File /media/jake/data/jake/mctnet_data/raw_images/Leptocotis_01_head_FEG190214_005a.nii already exists, so skipped this conversion
#
# Worker 6 doing job
# Starting conversion of /media/jake/1tb_ssd/mctv_analysis/head_scans/Vibilia_FEG191113_084_blurry
# ...
#
# Converted dicom /media/jake/1tb_ssd/mctv_analysis/head_scans/Schypholanceola_FEG190801_036_head to /media/jake/data/jake/mctnet_data/raw_images/Schypholanceola_FEG190801_036_head.nii
#
# Worker 0 doing job
# Starting conversion of /media/jake/1tb_ssd/mctv_analysis/head_scans/P_gracilis_FEG190730_032B_01_head
# ...
#
# Converted dicom /media/jake/1tb_ssd/mctv_analysis/head_scans/Vibilia_FEG191113_084_blurry to /media/jake/data/jake/mctnet_data/raw_images/Vibilia_FEG191113_084_blurry.nii
#
# Converted dicom /media/jake/1tb_ssd/mctv_analysis/head_scans/P_gracilis_FEG190730_032B_01_head to /media/jake/data/jake/mctnet_data/raw_images/P_gracilis_FEG190730_032B_01_head.nii
#
# Worker 0 doing job
# Starting conversion of /media/jake/1tb_ssd/mctv_analysis/head_scans/Cystisoma_FEG190730_030_head
# ...
#
# Converted dicom /media/jake/1tb_ssd/mctv_analysis/head_scans/Cystisoma_FEG190730_030_head to /media/jake/data/jake/mctnet_data/raw_images/Cystisoma_FEG190730_030_head.nii
#
# Worker 0 doing job
# Starting conversion of /media/jake/1tb_ssd/mctv_analysis/head_scans/Cystisoma_FEG190802_040_brain
# ...
#
# File /media/jake/data/jake/mctnet_data/raw_images/Cystisoma_FEG190802_040_brain.nii already exists, so skipped this conversion
#
# Worker 0 doing job
# Starting conversion of /media/jake/1tb_ssd/mctv_analysis/head_scans/P_crassipes_FEG190801_034_head
# ...
#
# File /media/jake/data/jake/mctnet_data/raw_images/P_crassipes_FEG190801_034_head.nii already exists, so skipped this conversion
#
# Worker 0 doing job
# Starting conversion of /media/jake/1tb_ssd/mctv_analysis/head_scans/Pronoe_sp_6_D
# ...
# Process Process-29:
# Traceback (most recent call last):
#   File "/usr/lib/python3.8/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/usr/lib/python3.8/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/tmp/ipykernel_767898/2836884920.py", line 10, in do_job
#     func(item)
#   File "/tmp/ipykernel_767898/1759632588.py", line 9, in convert_nifti_to_dicom
#     dicom2nifti.dicom_series_to_nifti(d, new_path, reorient_nifti=True)
#   File "/home/jake/projects/mctnet/venv/lib/python3.8/site-packages/dicom2nifti/convert_dicom.py", line 78, in dicom_series_to_nifti
#     return dicom_array_to_nifti(dicom_input, output_file, reorient_nifti)
#   File "/home/jake/projects/mctnet/venv/lib/python3.8/site-packages/dicom2nifti/convert_dicom.py", line 112, in dicom_array_to_nifti
#     if not are_imaging_dicoms(dicom_list):
#   File "/home/jake/projects/mctnet/venv/lib/python3.8/site-packages/dicom2nifti/convert_dicom.py", line 151, in are_imaging_dicoms
#     if common.is_philips(dicom_input):
#   File "/home/jake/projects/mctnet/venv/lib/python3.8/site-packages/dicom2nifti/common.py", line 102, in is_philips
#     header = dicom_input[0]
# IndexError: list index out of range
